# %% [markdown]
# # NeuralNetwork Class for Regression

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Requirements" data-toc-modified-id="Requirements-1">Requirements</a></span></li><li><span><a href="#Code-for-NeuralNetwork-Class-Saved-in-File-neuralnetworkA3.py" data-toc-modified-id="Code-for-NeuralNetwork-Class-Saved-in-File-neuralnetworkA3.py-2">Code for <code>NeuralNetwork</code> Class Saved in File <code>neuralnetworkA3.py</code></a></span></li><li><span><a href="#Example-Results" data-toc-modified-id="Example-Results-3">Example Results</a></span></li><li><span><a href="#Application-to-Seoul-Bike-Sharing-Demand-Data" data-toc-modified-id="Application-to-Seoul-Bike-Sharing-Demand-Data-4">Application to Seoul Bike Sharing Demand Data</a></span></li></ul></div>

# %% [markdown]
# ## Code for `NeuralNetwork` Class Saved in File `nn_regression.py`

# %%
# %%writefile NeuralNetwork_model.py

# import torch
# import numpy as np
# import pandas as pd

# class NeuralNetwork(torch.nn.Module):
#     """
#     A Neural Network Class for nonlinear regression type model. Creates model with user defined feed forward networks.

#     Methods:
#         initialize_weights(): Initializes weight for the Neural Network model.
#         to_torch(): Convert numpy array to torch.Tensor.
#         standardize(): Standardizes an input torch Tensor.
#         _forward(): Calculates outputs of each layer given inputs in X.
#         train(): Trains the model with given training and observed data.
#                  ** This method() will not be used in our model training.
#         distribute_T_for_backprop(): Distributes observed data to each pixel/sample for backpropagation purpose.
#         train_with_distributed_T(): Trains the model with given training and observed data in a distributed approach
#                                     (Observed data is distributed to each pixel/sample in each epoch before
#                                     initiating backpropagation).
#         predict(): Uses trained model to predict on given data.
#         get_performance_trace(): Provides model loss for each epoch.
#     """
    
#     def __init__(self, n_inputs, n_hiddens_list, n_outputs, activation_func='tanh', device='cpu'):
#         """
#         Creates a neural network with the given structure.

#         :param n_inputs: int. Number of attributes/predictors that will be used in the model.
#         :param n_hiddens_list: list. A list of number of units in each hidden layer. Each member of the list represents one
#                                hidden layer.
#         :param n_outputs: int. Number of output/prediction. Generally 1.
#         :param activation_func: str. Name of the activation function. Can take 'tanh'/'relu'/'leakyrelu'.
#         :param device: str. Name of the device to run the model. Either 'cpu'/'cuda'.
#         """
#         # Call parent class (torch.nn.Module) constructor
#         super().__init__()

#         self.device = device
#         print(f'Model running on {device}....')

#         # For printing
#         self.n_inputs = n_inputs
#         self.n_outputs = n_outputs
#         self.n_hidden_layers = n_hiddens_list

#         # To build list of layers, must use torch.nn.ModuleList, not plain list
#         self.hidden_layers = torch.nn.ModuleList()

#         if activation_func == 'tanh':
#             self.activation_func = torch.nn.Tanh()
#         elif activation_func == 'relu':
#             self.activation_func = torch.nn.ReLU()
#         elif activation_func == 'leakyrelu':
#             self.activation_func = torch.nn.LeakyReLU()
#         else:
#             raise Exception("Activation function should be 'tanh'/'relu'/'leakyrelu'")

#         for nh in n_hiddens_list:
#             self.hidden_layers.append(torch.nn.Sequential(
#                 torch.nn.Linear(n_inputs, nh),
#                 self.activation_func))

#             n_inputs = nh  # output of each hidden layer will be input of next hidden layer

#         self.output_layer = torch.nn.Linear(n_inputs, n_outputs)
#         self.initialize_weights()
        
#         self.performance_trace = []  # records standardized rmse records per epoch  
#         self.to(self.device)  # transfers the whole thing to 'cuda' if device='cuda'
#         self.fips_years = None  # modified in the train_with_distributed_T() function
#         self.n_epochs = None
        
#     def __repr__(self):
#         return 'NeuralNetwork({}, {}, {}, activation func={})'.format(self.n_inputs, self.n_hidden_layers,
#                                                                       self.n_outputs, self.activation_func)
#     def __str__(self):
#         s = self.__repr__()
#         if self.n_epochs > 0:  # self.total_epochs
#             s += '\n Trained for {} epochs.'.format(self.n_epochs)
#             s += '\n Final standardized training error {:.4g}.'.format(self.performance_trace[-1])
#         return s
    
#     def initialize_weights(self):
#         """
#         Initializes weight for the Neural Network model. For 'tanh' initializing method is 'xavier_normal'. For 'relu' and
#         'leakyrelu' initialization method is 'kaiming_normal'.
#         """
#         for m in self.modules():
#             if isinstance(m, torch.nn.Linear):
#                 if isinstance(self.activation_func, torch.nn.Tanh):
#                     torch.nn.init.xavier_normal_(m.weight)
#                 elif isinstance(self.activation_func, torch.nn.ReLU):
#                     torch.nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
#                 elif isinstance(self.activation_func, torch.nn.LeakyReLU):
#                     torch.nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='leaky_relu')

#     def to_torch(self, M, torch_type=torch.FloatTensor):
#         """
#         Convert numpy array to torch Tensor.

#         :param M: numpy array.
#         :param torch_type: torch data type. Default set to Float.

#         :return: A torch.Tensor.
#         """
#         if not isinstance(M, torch.Tensor):
#             M = torch.from_numpy(M).type(torch_type).to(self.device)
#         return M
    
#     def standardize(self, M):
#         """
#         Standardizes an input torch Tensor.

#         :param M: torch.tensor.

#         :return: Standardized torch Tensor, mean, and standard deviation values.
#         """
#         M_means = torch.mean(M, dim=0, keepdim=False)
#         M_stds = torch.std(M, dim=0, keepdim=False)

#         Ms = (M - M_means) / M_stds

#         return Ms, M_means, M_stds
    
#     def _forward(self, X):
#         """
#         Calculates outputs of each layer given inputs in X.

#         :param X: torch.Tensor. Standardized input array representing attributes as columns and samples as row.

#         :return: torch.Tensor. Standardized output array representing model prediction.
#         """
#         Y = X
#         for hidden_layers in self.hidden_layers:
#             Y = hidden_layers(Y)  # going through hidden layers

#         # Final output
#         Y = self.output_layer(Y)

#         return Y

#     def train(self, X, T, n_epochs, method='adam', learning_rate=None, verbose=True):
#         """
#         Trains the model with given training and observed data.
#         ** This method() will not be used in our model training.

#         :param X: torch.Tensor. Standardized input array representing attributes as columns and samples as row.
#         :param T: torch.Tensor. Standardized observed data (as array) to compare model prediction and initiate
#                   backpropagation.
#         :param n_epochs: int. Number of passes to take through all samples.
#         :param method: str. Optimization algorithm. Can take 'adam'/'sgd'.
#         :param learning_rate: float. Controls the step size of each update, only for sgd and adam.
#         :param verbose: boolean. If True, prints training progress statement.

#         :return: self. A trained NN model.
#         """
#         self.n_epochs = n_epochs
#         self.learning_rate = learning_rate

#         # If already not torch.Tensor converts X and T. If device=='cuda' will transfer to GPU. 
#         X = self.to_torch(X)
#         T = self.to_torch(T)

#         # Standardization
#         Xs, self.X_means, self.X_stds = self.standardize(X)
#         Ts, self.T_means, self.T_stds = self.standardize(T)

#         Xs.requires_grad_(True)

#         # Call the requested optimizer method to train the weights.
#         if method == 'sgd':
#             optimizer = torch.optim.SGD(self.parameters(), lr=learning_rate, momentum=0.9)
#         elif method == 'adam':
#             optimizer = torch.optim.Adam(self.parameters(), lr=learning_rate, weight_decay=0)
#         else:
#             raise Exception("method must be 'sgd', 'adam'")

#         mse_func = torch.nn.MSELoss()  # mse function

#         for epoch in range(self.n_epochs):
#             Ys = self._forward(Xs)
#             rmse_loss = torch.sqrt(mse_func(Ys, Ts))  # converting mse to rmse loss
#             print(rmse_loss)
#             rmse_loss.backward()  # Backpropagates the loss function

#             # using optimizer
#             optimizer.step()
#             optimizer.zero_grad()   # Reset the gradients to zero

#             # printing standardized rmse loss in training
#             epochs_to_print = 1000
#             if verbose & (((epoch + 1) % epochs_to_print) == 0):
#                 print(f'{method}: Epoch={epoch + 1} RMSE={rmse_loss.item():.5f}')

#             self.performance_trace.append(rmse_loss)

#         # Returning neural network object to allow applying other methods
#         # after training, such as:    Y = nnet.train(X, T, 100, 0.01).predict(X)
#         return self
    
#     @staticmethod
#     def distribute_T_for_backprop(input_torch_stack, observedGW_data_csv):
#         """
#         Distributes observed data to each pixel/sample for backpropagation purpose.

#         :param input_torch_stack: torch.Tensor. A stacked array generated after each epoch with prediction in
#                                   column 1 and fips_years in columns 2.
#         :param observedGW_data_csv: csv. Observed data (at county level).

#         :return: A numpy array of distributed T (observed) values for each pixel/sample.
#         """
#         # input_torch_stack is a numpy array having Ys output from self._forward() and 'fips_years' records stacked
#         predicted_df = pd.DataFrame(input_torch_stack, columns=['Ys', 'fips_years'])

#         # calculating total gw_withdrawal predicted (Ys_sum) using groupby on Ys
#         predicted_grp_df = predicted_df.groupby(by=['fips_years'])['Ys'].sum().reset_index()
#         predicted_grp_df = predicted_grp_df.rename(columns={'Ys': 'Ys_sum'})

#         # processing observed grounwater use data for counties
#         observed_df = pd.read_csv(observedGW_data_csv)

#         # 1st Merge
#         # merging grouped groundwater pumping dataframe with observed pumping dataframe.
#         merged_df = predicted_grp_df.merge(observed_df, on=['fips_years'], how='left')
#         merged_df = merged_df.sort_values(by=['fips_years']).reset_index(drop=True)
#         merged_df = merged_df[['fips_years', 'Ys_sum', 'total_gw_observed']]
#         #         print(merged_df.head(5))

#         # 2nd Merge
#         # merging the merged dataframe with pixel-wise dataframe
#         # needed for distributing observed data to each pixel based on percentage share on Ys_sum.
#         # required for backpropagation.
#         distributed_df = predicted_df.merge(merged_df, on=['fips_years'], how='left').reset_index()
#         #         print('distributed_df')
#         #         print(distributed_df.head(5))

#         distributed_df['share_of_totalgw'] = (distributed_df['Ys'] / distributed_df['Ys_sum']) \
#                                              * distributed_df['total_gw_observed']

#         T_share = distributed_df[
#             ['share_of_totalgw']].to_numpy()  # this is not standardized. Standardize it in train function

#         return T_share

#     def train_with_distributed_T(self, X, T_csv, n_epochs, method='sgd', learning_rate=None, verbose=True,
#                                  fips_years_col=-1, epochs_to_print=100):
#         """
#         Trains the model with given training and observed data in a distributed approach (Observed data is distributed
#         to each pixel/sample in each epoch before initiating backpropagation).

#         :param X: numpy array. Standardized input array representing attributes as columns and samples as row.
#         :param T_csv: csv. Observed data (at county level).
#         :param n_epochs: int. Number of passes to take through all samples.
#         :param method: str. Optimization algorithm. Can take 'adam'/'sgd'.
#         :param learning_rate: float. Controls the step size of each update, only for sgd and adam.
#         :param verbose: boolean. If True, prints training progress statement.
#         :param fips_years_col: int. Column index in X (torch.Tensor) array holding 'fips_years' attribute.
#                                This column is removed before standardizing and forward pass.
#         :param epochs_to_print: int. If verbose is True, training progress will be printed after this number of epochs.

#         :return: self. A trained NN model using distributed observed data approach.
#         """
#         self.n_epochs = n_epochs
#         self.learning_rate = learning_rate

#         # Creating fips_years unique list 
#         fips_years = X[:, fips_years_col:]
#         self.fips_years = fips_years
#         X = X[:, :fips_years_col]  # getting rid of fips_years from predictors

#         # If already not torch.Tensor converts X and T. If device=='cuda' will transfer to GPU. 
#         X = self.to_torch(X)  # is a torch tensor now

#         # Standardization X
#         Xs, self.X_means, self.X_stds = self.standardize(X)

#         Xs.requires_grad_(True)

#         # Call the requested optimizer method to train the weights.
#         if method == 'sgd':
#             optimizer = torch.optim.SGD(self.parameters(), lr=learning_rate, momentum=0.9)
#         elif method == 'adam':
#             optimizer = torch.optim.Adam(self.parameters(), lr=learning_rate, weight_decay=0)
#         else:
#             raise Exception("method must be 'sgd', 'adam'")

#         mse_func = torch.nn.MSELoss()  # mse function

#         for epoch in range(self.n_epochs):
#             Ys = self._forward(Xs)

#             # grouping Ys by fips_years codes
#             Ys_stack = np.hstack((Ys.cpu().detach(), self.fips_years))  # is a numpy arrary

#             # T (unstandardized, numpy array) is countywise observed gw pumping data distributed among each pixel.
#             # This distribution will be performed in each epoch, based on prediction share of Ys in Ys_sum.
#             T = self.distribute_T_for_backprop(Ys_stack, T_csv)

#             # converting to torch tensor and standardizing
#             T = self.to_torch(T)
#             Ts, self.T_means, self.T_stds = self.standardize(T)

#             # backpropagation
#             rmse_loss = torch.sqrt(mse_func(Ys, Ts))  # coverting mse to rmse loss
#             rmse_loss.backward()  # Backpropagates the loss function

#             # using optimizer
#             optimizer.step()
#             optimizer.zero_grad()  # Reset the gradients to zero

#             # printing standardized rmse loss in training
#             if verbose & (((epoch + 1) % epochs_to_print) == 0):
#                 print(f'{method}: Epoch={epoch + 1} RMSE={rmse_loss.item():.5f}')

#             self.performance_trace.append(rmse_loss)

#         return self

#     def predict(self, X, fips_years_arr=None):
#         """
#         Uses trained model to predict on given data.

#         :param X: numpy array. Standardized input array representing attributes as columns and samples as row. Must not
#                   have fips_years column.
#         :param fips_years_arr: numpy array. If the function/method is used on validation/testing data, must have this
#                                a fips_years array. Default set to None for training data (fips_years will come form
#                                self.fips_years)

#         :return: A numpy array of prediction (aggregated at county level).
#         """
#         if fips_years_arr is not None:
#             fips_years = fips_years_arr.squeeze()
#         else:
#             fips_years = self.fips_years.squeeze()

#         # Moving to torch
#         X = self.to_torch(X)

#         # Standardization
#         Xs = (X - self.X_means) / self.X_stds

#         Ys = self._forward(Xs)  # standardized result
#         Y = Ys * self.T_stds + self.T_means  # Unstandardizing
#         Y = Y.cpu().detach()  # prediction as numpy array for each pixel  

#         df = pd.DataFrame(Y, columns=['Y_predicted'])  # dataframe created to store pixel-wise results
#         df['fips_years'] = pd.Series(
#             fips_years)  # adding fips_years to dataframe for aggregating result to county level
#         df = df.groupby(by=['fips_years'])['Y_predicted'].mean().reset_index()  # prediction aggregated to county level
#         Y_predicted = df['Y_predicted'].to_numpy()

#         return Y_predicted  # predicted result as numpy array

#     def get_performance_trace(self):
#         """
#         Provides model loss for each epoch.

#         :return: A list of values of model error for all epoch.
#         """
#         performance = [loss.item() for loss in self.performance_trace]
#         return performance
# Out:
# Overwriting NeuralNetwork_model.py

# %% [markdown]
# # Distributed computing code

# %%
# %%writefile NeuralNetwork_distributed.py

import os
import torch
import numpy as np
import pandas as pd
import torch.distributed as dist
from torch.utils.data import DataLoader
from torch.utils.data.distributed import DistributedSampler
from torch.nn.parallel import DistributedDataParallel as DDP


class NeuralNetwork(torch.nn.Module):
    """
    A Neural Network Class for nonlinear regression type model. Creates model with user defined feed forward networks.

    Methods:
        initialize_weights(): Initializes weight for the Neural Network model.
        to_torch(): Convert numpy array to torch.Tensor.
        standardize(): Standardizes an input torch Tensor.
        _forward(): Calculates outputs of each layer given inputs in X.
        train(): Trains the model with given training and observed data.
                 ** This method() will not be used in our model training.
        distribute_T_for_backprop(): Distributes observed data to each pixel/sample for backpropagation purpose.
        train_with_distributed_T(): Trains the model with given training and observed data in a distributed approach
                                    (Observed data is distributed to each pixel/sample in each epoch before
                                    initiating backpropagation).
        predict(): Uses trained model to predict on given data.
        get_performance_trace(): Provides model loss for each epoch.
    """
    
    def __init__(self, n_inputs, n_hiddens_list, n_outputs, activation_func='tanh', device='cpu'):
        """
        Creates a neural network with the given structure.

        :param n_inputs: int. Number of attributes/predictors that will be used in the model.
        :param n_hiddens_list: list. A list of number of units in each hidden layer. Each member of the list represents one
                               hidden layer.
        :param n_outputs: int. Number of output/prediction. Generally 1.
        :param activation_func: str. Name of the activation function. Can take 'tanh'/'relu'/'leakyrelu'.
        :param device: str. Name of the device to run the model. Either 'cpu'/'cuda'.
        """
        # Call parent class (torch.nn.Module) constructor
        super().__init__()

        self.device = device
        print(f'Model running on {device}....')

        # For printing
        self.n_inputs = n_inputs
        self.n_outputs = n_outputs
        self.n_hidden_layers = n_hiddens_list

        # To build list of layers, must use torch.nn.ModuleList, not plain list
        self.hidden_layers = torch.nn.ModuleList()

        if activation_func == 'tanh':
            self.activation_func = torch.nn.Tanh()
        elif activation_func == 'relu':
            self.activation_func = torch.nn.ReLU()
        elif activation_func == 'leakyrelu':
            self.activation_func = torch.nn.LeakyReLU()
        else:
            raise Exception("Activation function should be 'tanh'/'relu'/'leakyrelu'")

        for nh in n_hiddens_list:
            self.hidden_layers.append(torch.nn.Sequential(
                torch.nn.Linear(n_inputs, nh),
                self.activation_func))

            n_inputs = nh  # output of each hidden layer will be input of next hidden layer

        self.output_layer = torch.nn.Linear(n_inputs, n_outputs)
        self.initialize_weights()
        
        self.performance_trace = []  # records standardized rmse records per epoch  
        self.to(self.device)  # transfers the whole thing to 'cuda' if device='cuda'
        
    def __repr__(self):
        return 'NeuralNetwork({}, {}, {}, activation func={})'.format(self.n_inputs, self.n_hidden_layers,
                                                                      self.n_outputs, self.activation_func)
    def __str__(self):
        s = self.__repr__()
        if self.n_epochs > 0:  # self.total_epochs
            s += '\n Trained for {} epochs.'.format(self.n_epochs)
            s += '\n Final standardized training error {:.4g}.'.format(self.performance_trace[-1])
        return s
    
    def initialize_weights(self):
        """
        Initializes weight for the Neural Network model. For 'tanh' initializing method is 'xavier_normal'. For 'relu' and
        'leakyrelu' initialization method is 'kaiming_normal'.
        """
        for m in self.modules():
            if isinstance(m, torch.nn.Linear):
                if isinstance(self.activation_func, torch.nn.Tanh):
                    torch.nn.init.xavier_normal_(m.weight)
                elif isinstance(self.activation_func, torch.nn.ReLU):
                    torch.nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                elif isinstance(self.activation_func, torch.nn.LeakyReLU):
                    torch.nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='leaky_relu')
    
    def forward(self, X):
        """
        Calculates outputs of each layer given inputs in X.

        :param X: torch.Tensor. Standardized input array representing attributes as columns and samples as row.

        :return: torch.Tensor. Standardized output array representing model prediction.
        """
        Y = X
        for hidden_layers in self.hidden_layers:
            Y = hidden_layers(Y)  # going through hidden layers

        # Final output
        Y = self.output_layer(Y)

        return Y
    ##########################
    
def ddp_setup(rank, world_size):
    os.environ['MASTER_ADDR'] = 'localhost'
    os.environ['MASTER_PORT'] = '12355' 
    dist.init_process_group("gloo", rank=rank, world_size=world_size)

def to_torch(M, torch_type=torch.FloatTensor, device='cpu'):
    """
    Convert numpy array to torch Tensor.

    :param M: numpy array.
    :param torch_type: torch data type. Default set to Float.

    :return: A torch.Tensor.
    """
    if not isinstance(M, torch.Tensor):
        M = torch.from_numpy(M).type(torch_type).to(device)
    return M

def standardize(M):
    """
    Standardizes an input torch Tensor.

    :param M: torch.tensor.

    :return: Standardized torch Tensor, mean, and standard deviation values.
    """
    M_means = torch.mean(M, dim=0, keepdim=False)
    M_stds = torch.std(M, dim=0, keepdim=False)

    Ms = (M - M_means) / M_stds

    return Ms, M_means, M_stds

    
def execute_dataloader(dataset, rank, world_size, num_workers, batch_size=None, pin_memory=False, shuffle=False):

    distributed_sampler = DistributedSampler(dataset, num_replicas=world_size, rank=rank, shuffle=shuffle, 
                                             drop_last=True)

    if batch_size is not None:
        dataloader = DataLoader(dataset, batch_size=batch_size, pin_memory=pin_memory, num_workers=num_workers, 
                                drop_last=True, shuffle=shuffle, sampler=distributed_sampler)
    else:
        batch_size = len(dataset)
        dataloader = DataLoader(dataset, batch_size=batch_size, pin_memory=pin_memory, num_workers=num_workers, 
                                drop_last=True, shuffle=shuffle, sampler=distributed_sampler)
    return dataloader


def cleanup():
    dist.destroy_process_group()
    

def distribute_T_for_backprop(input_torch_stack, observedGW_data_csv):
    """
    Distributes observed data to each pixel/sample for backpropagation purpose.

    :param input_torch_stack: torch.Tensor. A stacked array generated after each epoch with prediction in
                              column 1 and fips_years in columns 2.
    :param observedGW_data_csv: csv. Observed data (at county level).

    :return: A numpy array of distributed T (observed) values for each pixel/sample.
    """
    # input_torch_stack is a numpy array having Ys output from self.forward() and 'fips_years' records stacked
    predicted_df = pd.DataFrame(input_torch_stack, columns=['Ys', 'fips_years'])

    # calculating total gw_withdrawal predicted (Ys_sum) using groupby on Ys
    predicted_grp_df = predicted_df.groupby(by=['fips_years'])['Ys'].sum().reset_index()
    predicted_grp_df = predicted_grp_df.rename(columns={'Ys': 'Ys_sum'})

    # processing observed grounwater use data for counties
    observed_df = pd.read_csv(observedGW_data_csv)
    observed_df = to_torch(observed_df.values)
    observed_df = pd.DataFrame(observed_df, columns=['total_gw_observed', 'fips_years'])
    
    # 1st Merge
    # merging grouped groundwater pumping dataframe with observed pumping dataframe.
    merged_df = predicted_grp_df.merge(observed_df, on=['fips_years'], how='left')
    merged_df = merged_df[['fips_years', 'Ys_sum', 'total_gw_observed']]

    # 2nd Merge
    # merging the merged dataframe with pixel-wise dataframe
    # needed for distributing observed data to each pixel based on percentage share on Ys_sum.
    # required for backpropagation.
    distributed_df = predicted_df.merge(merged_df, on=['fips_years'], how='left').reset_index()
    distributed_df['share_of_totalgw'] = (distributed_df['Ys'] / distributed_df['Ys_sum']) \
                                         * distributed_df['total_gw_observed']

    T_share = distributed_df[
        ['share_of_totalgw']].to_numpy()  # this is not standardized. Standardize it in train function

    return T_share


def train_with_distributed_T(train_data, observed_data_csv, n_epochs,
                             n_inputs, n_hiddens_list, n_outputs, 
                             rank, world_size, batch_size, num_workers,
                             activation_func='tanh', device='cpu',
                             method='sgd', learning_rate=None, verbose=True,
                             fips_years_col=-1, epochs_to_print=100, initialize_ddp_setup=True):
    """
    Trains the model with given training and observed data in a distributed approach (Observed data is distributed
    to each pixel/sample in each epoch before initiating backpropagation).

    :param train_data: numpy array. Standardized input array representing attributes as columns and samples as row.
    :param observed_data_csv: csv. Observed data (at county level).
    :param n_epochs: int. Number of passes to take through all samples.
    :param method: str. Optimization algorithm. Can take 'adam'/'sgd'.
    :param learning_rate: float. Controls the step size of each update, only for sgd and adam.
    :param verbose: boolean. If True, prints training progress statement.
    :param fips_years_col: int. Column index in X (torch.Tensor) array holding 'fips_years' attribute.
                           This column is removed before standardizing and forward pass.
    :param epochs_to_print: int. If verbose is True, training progress will be printed after this number of epochs.

    :return: self. A trained NN model using distributed observed data approach.
    """  
    if initialize_ddp_setup:
        ddp_setup(rank, world_size)
    
    # If already not torch.Tensor converts X and T. If device=='cuda' will transfer to GPU. 
    train_data = to_torch(train_data, device=device)  # is a torch tensor now
    
    # Dataloader
    train_dataloader = execute_dataloader(dataset=train_data, rank=rank, world_size=world_size, num_workers=num_workers,
                                          batch_size=batch_size, pin_memory=False, shuffle=False)
    
    ##############
    # Instantiating model, wrapping it with DDP, and moving it to the right device (cuda/gpu)
    if device == 'cpu':
        nn_model = NeuralNetwork(n_inputs, n_hiddens_list, n_outputs, activation_func, device)
    elif devide == 'cuda':
        nn_model = NeuralNetwork(n_inputs, n_hiddens_list, n_outputs, activation_func, device).to(rank)
    # wrap the model with DDP
    # device_ids tell DDP where is the model
    # output_device tells DDP where to output, in this case, it is rank
    # find_unused_parameters=True instructs DDP to find unused output of the forward() function of any module in the model
    if device == 'cpu':
        nn_model = DDP(nn_model, device_ids=None, output_device=None, find_unused_parameters=True)
    elif device == 'cuda':
        nn_model = DDP(nn_model, device_ids=[rank], output_device=rank, find_unused_parameters=True)
    ##############
        
    # Call the requested optimizer method to train the weights.
    if method == 'sgd':
        optimizer = torch.optim.SGD(nn_model.parameters(), lr=learning_rate, momentum=0.9)
    elif method == 'adam':
        optimizer = torch.optim.Adam(nn_model.parameters(), lr=learning_rate, weight_decay=0)
    else:
        raise Exception("method must be 'sgd', 'adam'")

    # mse function
    mse_func = torch.nn.MSELoss()  

    for epoch in range(n_epochs):
        
        # if using DistributedSampler, have to tell it which epoch this is
        train_dataloader.sampler.set_epoch(epoch) 

        for step, X in enumerate(train_dataloader):
            
            # Separating fips_years column 
            fips_years = X[:, fips_years_col:]
            X = X[:, :fips_years_col]  # getting rid of fips_years from predictors
            # Standardization X
            Xs, X_means, X_stds = standardize(X)
            Xs.requires_grad_(True)
            
            # Forward pass 
            Ys = nn_model(Xs)

            # grouping Ys by fips_years codes
            Ys_stack = np.hstack((Ys.cpu().detach(), fips_years.cpu().detach()))  # is a numpy arrary

            # T (unstandardized, numpy array) is countywise observed gw pumping data distributed among each pixel.
            # This distribution will be performed in each epoch, based on prediction share of Ys in Ys_sum.
            T = distribute_T_for_backprop(Ys_stack, observed_data_csv)

            # converting to torch tensor and standardizing
            T = to_torch(T, device=device)
            Ts, T_means, T_stds = standardize(T)

            # backpropagation
            rmse_loss = torch.sqrt(mse_func(Ys, Ts))  # coverting mse to rmse loss
            rmse_loss.backward()  # Backpropagates the loss function
            
            # using optimizer
            optimizer.step()
            optimizer.zero_grad()  # Reset the gradients to zero

        # printing standardized rmse loss in training
        if verbose & (((epoch + 1) % epochs_to_print) == 0):
            print(f'{method}: Epoch={epoch + 1} RMSE={rmse_loss.item():.5f}')
        cleanup()
        
#         self.performance_trace.append(rmse_loss)

#     return self

# def predict(self, X, fips_years_arr=None):
#     """
#     Uses trained model to predict on given data.

#     :param X: numpy array. Standardized input array representing attributes as columns and samples as row. Must not
#               have fips_years column.
#     :param fips_years_arr: numpy array. If the function/method is used on validation/testing data, must have this
#                            a fips_years array. Default set to None for training data (fips_years will come form
#                            self.fips_years)

#     :return: A numpy array of prediction (aggregated at county level).
#     """
#     if fips_years_arr is not None:
#         fips_years = fips_years_arr.squeeze()
#     else:
#         fips_years = self.fips_years.squeeze()

#     # Moving to torch
#     X = self.to_torch(X)

#     # Standardization
#     Xs = (X - self.X_means) / self.X_stds

#     Ys = self._forward(Xs)  # standardized result
#     Y = Ys * self.T_stds + self.T_means  # Unstandardizing
#     Y = Y.cpu().detach()  # prediction as numpy array for each pixel  

#     df = pd.DataFrame(Y, columns=['Y_predicted'])  # dataframe created to store pixel-wise results
#     df['fips_years'] = pd.Series(
#         fips_years)  # adding fips_years to dataframe for aggregating result to county level
#     df = df.groupby(by=['fips_years'])['Y_predicted'].mean().reset_index()  # prediction aggregated to county level
#     Y_predicted = df['Y_predicted'].to_numpy()

#     return Y_predicted  # predicted result as numpy array

# def get_performance_trace(self):
#     """
#     Provides model loss for each epoch.

#     :return: A list of values of model error for all epoch.
#     """
#     performance = [loss.item() for loss in self.performance_trace]
#     return performance
# Out:
# Overwriting NeuralNetwork_distributed.py

# %% [markdown]
# ## Example Results

# %% [markdown]
# Here we test the `NeuralNetwork` class with some simple data.

# %%
import time
import torch
import numpy as np
import pandas as pd 

import NeuralNetwork_distributed as nn
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def rmse(Y_predicted, T):
    return np.sqrt(np.mean((T - Y_predicted)**2))

def create_model_input(predictor_csv, observed_csv=None, predictor_drop_columns=('fips', 'Year'),
                       use_for_testing=False):
    """
    Generates numpy array of predictors and observed data, n_inputs number, and fips_years_array.
    Array of observed data and fip_years are only generated if use_for_testing is True.
    ** set use_for_testing = True for testing/predicting on new data.

    :param predictor_csv: File path of predictor csv.
    :param observed_csv: Default set to None. File path of observed data csv used for model testing.
                         Set a file path and use_for_testing=True for enabling this option.
    :param predictor_drop_columns: Tuple/List of data/columns to drop. Default set to ('fips', 'Year'). To drop
                                   additional data/columns add them with ('fips', 'Year').
    :param use_for_testing: Set to True if data will be used for model testing/predicting on new data.

    :return: if use_for_testing=False, returns -- predictor_arr, n_inputs
             if use_for_testing=True, returns -- predictor_arr, n_inputs, observed_arr, fips_years_arr
    """
    predictor_df = pd.read_csv(predictor_csv)

    # if data is training, fips_years will be extracted in train_with_distributed_T() function of NeuralNetwork class
    fips_years_arr = None

    if use_for_testing:
        fips_years_arr = predictor_df[['fips_years']].to_numpy()
        predictor_drop_columns = predictor_drop_columns + ['fips_years']

    predictor_df = predictor_df.drop(columns=predictor_drop_columns)
    columns = list(predictor_df.columns)
    print(f'Using predictors: {columns[:-1]}')
    predictor_arr = predictor_df[columns].to_numpy()
    n_inputs = len(columns) - 1

    if observed_csv is None:
        return predictor_arr, n_inputs
    else:
        observed_df = pd.read_csv(observed_csv)
        observed_arr = observed_df[['total_gw_observed']].to_numpy()

        return predictor_arr, n_inputs, observed_arr, fips_years_arr

# %%
# Trial model run

train_arr, n_inputs = create_model_input(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_data.csv',
                                     observed_csv=None,
                                     predictor_drop_columns=['fips', 'Year'], use_for_testing=False)

# Experiment on training data with small sample size
train_arr = train_arr[0:200000, :]
unq = list(np.unique(train_arr[:, -1]))
obsv_csv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv.csv'

obsv_df = pd.read_csv(obsv_csv)
obsv_df = obsv_df[obsv_df['fips_years'].isin(unq)]
obsv_df.to_csv(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv2.csv', index=False)
obsv_csv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv2.csv'
# Out:
# Using predictors: ['GPM_PRECIP', 'MODIS_Day_LST', 'MODIS_NDWI', 'PRISM_PRECIP', 'SSEBOP_ET', 'USDA_cropland', 'USDA_developed']

# %%
start_time = time.time()

nn.train_with_distributed_T(train_data=train_arr, observed_data_csv=obsv_csv, n_epochs=2,
                             n_inputs=n_inputs, n_hiddens_list=[50, 10], n_outputs=1, 
                             rank=0, world_size=1, batch_size=None, num_workers=0,
                             activation_func='tanh', device='cpu',
                             method='adam', learning_rate=0.01, verbose=True,
                             fips_years_col=-1, epochs_to_print=100, initialize_ddp_setup=True)

end_time = time.time()
time_taken = end_time - start_time

print('Time Taken', round((time_taken)/60, 2), 'mins')
# Out:
# Model running on cpu....
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [42], line 3
#       1 start_time = time.time()
# ----> 3 nn.train_with_distributed_T(train_data=train_arr, observed_data_csv=obsv_csv, n_epochs=2,
#       4                              n_inputs=n_inputs, n_hiddens_list=[50, 10], n_outputs=1,
#       5                              rank=0, world_size=1, batch_size=None, num_workers=0,
#       6                              activation_func='tanh', device='cpu',
#       7                              method='adam', learning_rate=0.01, verbose=True,
#       8                              fips_years_col=-1, epochs_to_print=100, initialize_ddp_setup=True)
#      10 end_time = time.time()
#      11 time_taken = end_time - start_time
#
# File H:\WestUS_wateruse\python_scripts\NeuralNetwork_distributed.py:308, in train_with_distributed_T(train_data, observed_data_csv, n_epochs, n_inputs, n_hiddens_list, n_outputs, rank, world_size, batch_size, num_workers, activation_func, device, method, learning_rate, verbose, fips_years_col, epochs_to_print, initialize_ddp_setup)
#     306 if verbose & (((epoch + 1) % epochs_to_print) == 0):
#     307     print(f'{method}: Epoch={epoch + 1} RMSE={rmse_loss.item():.5f}')
# --> 308 cleanup()
#
# File H:\WestUS_wateruse\python_scripts\NeuralNetwork_distributed.py:170, in cleanup()
#     169 def cleanup():
# --> 170     dist.destroy_process_group()
#
# File ~\Anaconda3\envs\US_wateruse\lib\site-packages\torch\distributed\distributed_c10d.py:797, in destroy_process_group(group)
#     794 else:
#     795     pg = group
# --> 797 assert pg is not None
#     798 if _pg_map.get(pg, None) is None:
#     799     raise RuntimeError("Invalid process group specified")
#
# AssertionError:

# %%
import torch
import pandas as pd
from torch.utils.data import DataLoader
from torch.utils.data.distributed import DistributedSampler


sample = pd.read_csv(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv.csv')
sample

# %%
sample_arr = sample[['total_gw_observed', 'fips_years']].to_numpy()
print(type(sample_arr))

sampler = DistributedSampler(sample_arr, num_replicas=1, rank=0, shuffle=False, drop_last=False)
dataloader = DataLoader(sample_arr, batch_size=10, pin_memory=False, num_workers=1, drop_last=False, shuffle=False, 
                        sampler=sampler)
i = 0    
for item in dataloader:
    i+=1
    print(i)
    print(item)
# Out:
# <class 'numpy.ndarray'>
# 1
# tensor([[2.0362e+01, 4.0032e+07],
#         [6.0970e-01, 4.0052e+07],
#         [5.1843e-01, 4.0052e+07],
#         [3.9939e+00, 4.0152e+07],
#         [2.8653e+00, 4.0172e+07],
#         [1.5500e+01, 4.0192e+07],
#         [7.4625e+00, 4.0232e+07],
#         [5.6568e+00, 4.0232e+07],
#         [4.7596e+00, 4.0252e+07],
#         [1.7401e+01, 4.0272e+07]], dtype=torch.float64)
# 2
# tensor([[1.1953e+01, 4.0272e+07],
#         [2.0021e+01, 6.0012e+07],
#         [7.5868e-02, 6.0032e+07],
#         [4.7521e+00, 6.0032e+07],
#         [6.4544e+00, 6.0052e+07],
#         [1.4558e+01, 6.0052e+07],
#         [8.8757e+01, 6.0072e+07],
#         [2.3119e+02, 6.0072e+07],
#         [1.6036e+00, 6.0092e+07],
#         [5.7174e+01, 6.0112e+07]], dtype=torch.float64)
# 3
# tensor([[2.7987e+02, 6.0112e+07],
#         [1.9883e+01, 6.0132e+07],
#         [7.6682e+00, 6.0172e+07],
#         [8.7966e+01, 6.0212e+07],
#         [1.5501e+02, 6.0252e+07],
#         [2.0566e+00, 6.0272e+07],
#         [6.1271e+01, 6.0292e+07],
#         [1.0199e+02, 6.0292e+07],
#         [1.9906e+02, 6.0312e+07],
#         [7.3576e+00, 6.0352e+07]], dtype=torch.float64)
# 4
# tensor([[9.9739e+01, 6.0372e+07],
#         [1.8585e+02, 6.0392e+07],
#         [7.8342e+00, 6.0412e+07],
#         [2.7822e+01, 6.0412e+07],
#         [1.8893e+02, 6.0472e+07],
#         [1.4879e+01, 6.0492e+07],
#         [6.8756e+00, 6.0512e+07],
#         [5.5673e+00, 6.0572e+07],
#         [2.1269e+01, 6.0572e+07],
#         [1.9832e+02, 6.0592e+07]], dtype=torch.float64)
# 5
# tensor([[1.9365e+02, 6.0592e+07],
#         [1.0859e+01, 6.0612e+07],
#         [3.3202e+01, 6.0612e+07],
#         [1.4744e+01, 6.0632e+07],
#         [3.2363e+01, 6.0652e+07],
#         [1.2840e+01, 6.0732e+07],
#         [2.0095e+01, 6.0752e+07],
#         [2.6452e+01, 6.0752e+07],
#         [1.9860e+02, 6.0772e+07],
#         [2.6965e+02, 6.0772e+07]], dtype=torch.float64)
# 6
# tensor([[2.8704e+01, 6.0792e+07],
#         [1.1835e+01, 6.0792e+07],
#         [1.3025e+01, 6.0812e+07],
#         [2.4927e+01, 6.0812e+07],
#         [3.7881e+01, 6.0832e+07],
#         [3.4453e+01, 6.0852e+07],
#         [4.6469e+01, 6.0872e+07],
#         [7.2022e+00, 6.0912e+07],
#         [9.1939e+00, 6.0912e+07],
#         [1.1953e+01, 6.0932e+07]], dtype=torch.float64)
# 7
# tensor([[1.1815e+01, 6.0932e+07],
#         [1.2922e+02, 6.0952e+07],
#         [1.6782e+02, 6.0952e+07],
#         [2.3254e+02, 6.0992e+07],
#         [3.9890e+02, 6.1012e+07],
#         [1.3390e+00, 6.1052e+07],
#         [1.3866e+02, 6.1072e+07],
#         [1.3360e+02, 6.1072e+07],
#         [9.8773e-01, 6.1092e+07],
#         [6.3988e+01, 6.1112e+07]], dtype=torch.float64)
# 8
# tensor([[1.8356e+02, 6.1152e+07],
#         [1.3352e+01, 8.0012e+07],
#         [7.9299e+00, 8.0012e+07],
#         [6.5137e+01, 8.0032e+07],
#         [7.7613e+00, 8.0052e+07],
#         [4.8823e-01, 8.0072e+07],
#         [2.0466e+01, 8.0092e+07],
#         [5.9838e-01, 8.0132e+07],
#         [4.1093e-01, 8.0132e+07],
#         [1.0778e+00, 8.0152e+07]], dtype=torch.float64)
# 9
# tensor([[1.0245e+01, 8.0172e+07],
#         [6.6023e-01, 8.0192e+07],
#         [2.5132e+01, 8.0212e+07],
#         [1.5242e+01, 8.0232e+07],
#         [3.9693e-01, 8.0272e+07],
#         [4.8936e+00, 8.0312e+07],
#         [1.6988e+01, 8.0352e+07],
#         [1.5639e+00, 8.0372e+07],
#         [1.5202e+00, 8.0392e+07],
#         [1.9730e+00, 8.0392e+07]], dtype=torch.float64)
# 10
# tensor([[5.9807e+00, 8.0412e+07],
#         [5.0123e-01, 8.0432e+07],
#         [4.9079e-01, 8.0432e+07],
#         [7.2867e-01, 8.0452e+07],
#         [2.5225e+00, 8.0472e+07],
#         [3.7403e-01, 8.0492e+07],
#         [7.0871e-01, 8.0512e+07],
#         [6.0748e-01, 8.0532e+07],
#         [1.0534e-01, 8.0572e+07],
#         [4.5661e+00, 8.0592e+07]], dtype=torch.float64)
# 11
# tensor([[3.2211e+00, 8.0592e+07],
#         [6.4225e-01, 8.0612e+07],
#         [2.7968e+00, 8.0652e+07],
#         [7.8755e+00, 8.0652e+07],
#         [6.5544e-01, 8.0672e+07],
#         [5.4254e-01, 8.0672e+07],
#         [3.2433e-01, 8.0692e+07],
#         [1.3191e-01, 8.0712e+07],
#         [7.1606e-01, 8.0732e+07],
#         [9.8845e-01, 8.0732e+07]], dtype=torch.float64)
# 12
# tensor([[1.6964e+01, 8.0752e+07],
#         [1.8925e+01, 8.0752e+07],
#         [4.3145e-01, 8.0792e+07],
#         [2.1874e-01, 8.0812e+07],
#         [9.9837e-02, 8.0812e+07],
#         [1.9051e-01, 8.0832e+07],
#         [3.2548e-01, 8.0852e+07],
#         [5.2390e-01, 8.0932e+07],
#         [7.1824e-01, 8.0972e+07],
#         [2.1320e+00, 8.1012e+07]], dtype=torch.float64)
# 13
# tensor([[3.5385e-01, 8.1032e+07],
#         [3.5881e-01, 8.1032e+07],
#         [6.1842e+01, 8.1052e+07],
#         [2.8384e-01, 8.1072e+07],
#         [1.7346e-01, 8.1072e+07],
#         [4.1197e-02, 8.1112e+07],
#         [2.8118e-01, 8.1132e+07],
#         [1.5350e+01, 8.1152e+07],
#         [3.8554e+01, 8.1152e+07],
#         [2.7582e+00, 8.1172e+07]], dtype=torch.float64)
# 14
# tensor([[1.6621e+00, 8.1192e+07],
#         [2.7003e+00, 8.1232e+07],
#         [4.7613e+00, 8.1232e+07],
#         [4.8436e+01, 8.1252e+07],
#         [5.0209e+01, 1.6001e+08],
#         [5.6049e+01, 1.6001e+08],
#         [7.5283e-01, 1.6003e+08],
#         [2.8063e+01, 1.6005e+08],
#         [1.8085e+00, 1.6007e+08],
#         [1.2102e+02, 1.6011e+08]], dtype=torch.float64)
# 15
# tensor([[1.1094e+02, 1.6011e+08],
#         [8.5457e+00, 1.6013e+08],
#         [2.2542e-01, 1.6015e+08],
#         [3.3514e+00, 1.6017e+08],
#         [1.5636e+01, 1.6021e+08],
#         [1.9797e+01, 1.6023e+08],
#         [2.4019e+01, 1.6023e+08],
#         [4.8265e+01, 1.6025e+08],
#         [9.3113e+01, 1.6025e+08],
#         [1.8049e+02, 1.6027e+08]], dtype=torch.float64)
# 16
# tensor([[2.3298e+02, 1.6027e+08],
#         [1.2678e+01, 1.6029e+08],
#         [9.8840e+01, 1.6031e+08],
#         [1.1994e+02, 1.6031e+08],
#         [1.0587e+01, 1.6033e+08],
#         [1.6158e+01, 1.6039e+08],
#         [1.7239e+01, 1.6039e+08],
#         [2.9628e+01, 1.6041e+08],
#         [7.6917e+00, 1.6045e+08],
#         [8.6485e+01, 1.6047e+08]], dtype=torch.float64)
# 17
# tensor([[1.9088e+02, 1.6051e+08],
#         [1.5149e+02, 1.6051e+08],
#         [6.9857e+01, 1.6053e+08],
#         [7.3527e+01, 1.6053e+08],
#         [1.5209e+01, 1.6055e+08],
#         [4.6383e+00, 1.6057e+08],
#         [5.9568e+01, 1.6057e+08],
#         [4.7944e+01, 1.6063e+08],
#         [1.2633e+02, 1.6065e+08],
#         [9.3325e+00, 1.6069e+08]], dtype=torch.float64)
# 18
# tensor([[3.4632e+01, 1.6071e+08],
#         [6.2581e+00, 1.6073e+08],
#         [6.1474e+01, 1.6075e+08],
#         [1.0327e+02, 1.6077e+08],
#         [1.2902e+02, 1.6077e+08],
#         [3.8558e-01, 1.6079e+08],
#         [5.4052e+01, 1.6081e+08],
#         [8.9624e+01, 1.6083e+08],
#         [4.7073e-01, 1.6085e+08],
#         [4.8783e-01, 2.0001e+08]], dtype=torch.float64)
# 19
# tensor([[8.3034e-02, 2.0001e+08],
#         [2.1626e+01, 2.0009e+08],
#         [2.1455e+01, 2.0009e+08],
#         [2.4578e-02, 2.0011e+08],
#         [0.0000e+00, 2.0011e+08],
#         [1.6715e+00, 2.0013e+08],
#         [8.3808e-01, 2.0015e+08],
#         [7.1808e-01, 2.0017e+08],
#         [2.2377e+01, 2.0023e+08],
#         [2.6414e+01, 2.0023e+08]], dtype=torch.float64)
# 20
# tensor([[2.8255e+00, 2.0025e+08],
#         [7.1183e+00, 2.0027e+08],
#         [6.4253e-02, 2.0031e+08],
#         [4.1609e+00, 2.0037e+08],
#         [4.3280e+00, 2.0037e+08],
#         [6.1989e+00, 2.0039e+08],
#         [3.1598e+00, 2.0041e+08],
#         [3.2837e+00, 2.0041e+08],
#         [1.0672e+00, 2.0043e+08],
#         [3.2281e+00, 2.0045e+08]], dtype=torch.float64)
# 21
# tensor([[8.5940e+01, 2.0047e+08],
#         [0.0000e+00, 2.0049e+08],
#         [1.2807e+00, 2.0053e+08],
#         [1.1489e+02, 2.0055e+08],
#         [9.4410e+01, 2.0055e+08],
#         [4.6583e+01, 2.0057e+08],
#         [6.6356e-01, 2.0059e+08],
#         [5.8175e-01, 2.0059e+08],
#         [1.4683e+01, 2.0061e+08],
#         [1.0527e+01, 2.0061e+08]], dtype=torch.float64)
# 22
# tensor([[8.4185e+00, 2.0065e+08],
#         [9.3536e+01, 2.0067e+08],
#         [8.1394e+01, 2.0069e+08],
#         [1.8260e-02, 2.0073e+08],
#         [2.2825e-02, 2.0073e+08],
#         [1.9663e+01, 2.0075e+08],
#         [2.3125e+00, 2.0077e+08],
#         [1.9962e+00, 2.0077e+08],
#         [1.8291e+02, 2.0081e+08],
#         [1.3085e+02, 2.0081e+08]], dtype=torch.float64)
# 23
# tensor([[3.2532e+00, 2.0087e+08],
#         [2.2442e+00, 2.0087e+08],
#         [1.1870e+00, 2.0089e+08],
#         [1.0315e+01, 2.0091e+08],
#         [7.9877e+01, 2.0093e+08],
#         [1.1031e+01, 2.0095e+08],
#         [1.0378e+01, 2.0095e+08],
#         [4.3664e+01, 2.0097e+08],
#         [0.0000e+00, 2.0099e+08],
#         [1.1431e+01, 2.0101e+08]], dtype=torch.float64)
# 24
# tensor([[5.6483e+00, 2.0103e+08],
#         [4.4627e+00, 2.0103e+08],
#         [7.2745e-01, 2.0105e+08],
#         [3.3395e+00, 2.0109e+08],
#         [1.7952e+01, 2.0113e+08],
#         [1.8339e+01, 2.0113e+08],
#         [1.1998e+00, 2.0117e+08],
#         [7.0977e+01, 2.0119e+08],
#         [2.6621e-02, 2.0121e+08],
#         [2.6621e-02, 2.0121e+08]], dtype=torch.float64)
# 25
# tensor([[6.4041e-01, 2.0123e+08],
#         [7.2533e-02, 2.0125e+08],
#         [3.3743e-01, 2.0127e+08],
#         [3.5993e-01, 2.0127e+08],
#         [3.4818e+01, 2.0129e+08],
#         [0.0000e+00, 2.0133e+08],
#         [6.2533e+00, 2.0137e+08],
#         [7.7126e+00, 2.0137e+08],
#         [7.2994e-03, 2.0139e+08],
#         [3.2172e+00, 2.0143e+08]], dtype=torch.float64)
# 26
# tensor([[5.0018e+01, 2.0145e+08],
#         [4.5090e+01, 2.0145e+08],
#         [3.8748e+00, 2.0147e+08],
#         [6.2665e+01, 2.0151e+08],
#         [7.0358e+00, 2.0153e+08],
#         [2.6016e+01, 2.0155e+08],
#         [4.3570e+00, 2.0161e+08],
#         [1.6540e+00, 2.0163e+08],
#         [1.7666e+00, 2.0163e+08],
#         [6.5580e+00, 2.0165e+08]], dtype=torch.float64)
# 27
# tensor([[7.5413e+00, 2.0165e+08],
#         [1.0019e-01, 2.0167e+08],
#         [3.2413e+01, 2.0171e+08],
#         [1.9250e+01, 2.0173e+08],
#         [1.3081e+02, 2.0175e+08],
#         [9.2483e+00, 2.0177e+08],
#         [6.3452e+00, 2.0177e+08],
#         [3.7646e+01, 2.0179e+08],
#         [1.2001e+00, 2.0183e+08],
#         [1.7026e+00, 2.0183e+08]], dtype=torch.float64)
# 28
# tensor([[5.7370e+01, 2.0185e+08],
#         [8.8888e+01, 2.0187e+08],
#         [1.4459e+02, 2.0189e+08],
#         [4.0822e+01, 2.0193e+08],
#         [4.2561e+01, 2.0193e+08],
#         [3.5193e+00, 2.0195e+08],
#         [1.6123e+00, 2.0197e+08],
#         [1.3227e+00, 2.0197e+08],
#         [2.6390e+01, 2.0199e+08],
#         [2.1510e+01, 2.0199e+08]], dtype=torch.float64)
# 29
# tensor([[2.6322e+00, 2.0201e+08],
#         [2.9769e+01, 2.0203e+08],
#         [1.3654e+01, 2.0209e+08],
#         [4.1092e-01, 3.0001e+08],
#         [6.8591e-01, 3.0003e+08],
#         [3.0521e-01, 3.0003e+08],
#         [1.4958e+00, 3.0007e+08],
#         [6.2507e-01, 3.0009e+08],
#         [2.5512e-02, 3.0011e+08],
#         [1.1162e-01, 3.0011e+08]], dtype=torch.float64)
# 30
# tensor([[7.7726e-01, 3.0013e+08],
#         [2.2484e-01, 3.0015e+08],
#         [7.1865e-01, 3.0019e+08],
#         [3.7413e-01, 3.0021e+08],
#         [2.6660e-01, 3.0021e+08],
#         [2.0830e+00, 3.0023e+08],
#         [3.7506e-01, 3.0025e+08],
#         [4.0645e-01, 3.0027e+08],
#         [3.4646e-01, 3.0027e+08],
#         [2.4180e+00, 3.0029e+08]], dtype=torch.float64)
# 31
# tensor([[4.2430e+00, 3.0031e+08],
#         [7.3730e-02, 3.0033e+08],
#         [3.6771e-01, 3.0035e+08],
#         [2.0215e-01, 3.0035e+08],
#         [1.7382e-01, 3.0039e+08],
#         [2.5173e-01, 3.0041e+08],
#         [7.6011e-01, 3.0043e+08],
#         [3.4969e-01, 3.0045e+08],
#         [3.6185e+00, 3.0047e+08],
#         [1.7799e+00, 3.0049e+08]], dtype=torch.float64)
# 32
# tensor([[1.1240e+00, 3.0049e+08],
#         [1.4322e-01, 3.0051e+08],
#         [7.7120e-02, 3.0051e+08],
#         [2.8780e-01, 3.0053e+08],
#         [4.5743e-01, 3.0057e+08],
#         [4.7912e-01, 3.0059e+08],
#         [1.5749e-01, 3.0059e+08],
#         [1.3470e+00, 3.0061e+08],
#         [2.8834e-01, 3.0061e+08],
#         [7.8199e+00, 3.0063e+08]], dtype=torch.float64)
# 33
# tensor([[7.9106e+00, 3.0063e+08],
#         [3.8720e-01, 3.0065e+08],
#         [8.7475e-01, 3.0067e+08],
#         [6.8015e-01, 3.0067e+08],
#         [6.3681e-02, 3.0069e+08],
#         [5.2795e-01, 3.0071e+08],
#         [1.9235e-01, 3.0071e+08],
#         [3.3893e-01, 3.0073e+08],
#         [2.7349e-01, 3.0075e+08],
#         [3.3823e-01, 3.0075e+08]], dtype=torch.float64)
# 34
# tensor([[7.3213e-01, 3.0079e+08],
#         [2.6651e-01, 3.0079e+08],
#         [6.8278e-01, 3.0083e+08],
#         [8.8771e-01, 3.0085e+08],
#         [2.8782e-01, 3.0087e+08],
#         [1.1887e+00, 3.0089e+08],
#         [3.9811e-01, 3.0089e+08],
#         [1.9023e+00, 3.0091e+08],
#         [2.3719e+00, 3.0093e+08],
#         [5.3036e-01, 3.0093e+08]], dtype=torch.float64)
# 35
# tensor([[1.2411e+00, 3.0095e+08],
#         [6.7508e-01, 3.0095e+08],
#         [4.4841e-01, 3.0097e+08],
#         [3.3417e-01, 3.0097e+08],
#         [5.2285e-01, 3.0099e+08],
#         [4.6917e-01, 3.0101e+08],
#         [6.4457e-01, 3.0103e+08],
#         [5.7464e-01, 3.0105e+08],
#         [1.3419e+00, 3.0107e+08],
#         [4.7713e-01, 3.0107e+08]], dtype=torch.float64)
# 36
# tensor([[1.5192e+00, 3.0111e+08],
#         [1.5229e+02, 3.1001e+08],
#         [4.9977e+01, 3.1003e+08],
#         [3.9921e+00, 3.1005e+08],
#         [1.0399e+01, 3.1009e+08],
#         [4.6161e+01, 3.1011e+08],
#         [7.0971e+01, 3.1011e+08],
#         [4.4460e+01, 3.1013e+08],
#         [8.7565e+00, 3.1015e+08],
#         [8.5812e+00, 3.1015e+08]], dtype=torch.float64)
# 37
# tensor([[1.7846e+01, 3.1017e+08],
#         [1.1487e+02, 3.1019e+08],
#         [1.1179e+01, 3.1021e+08],
#         [2.7904e+01, 3.1021e+08],
#         [4.5611e+01, 3.1023e+08],
#         [2.9001e+01, 3.1023e+08],
#         [1.5338e+01, 3.1025e+08],
#         [1.3932e+01, 3.1025e+08],
#         [1.9779e+01, 3.1027e+08],
#         [4.7020e+01, 3.1027e+08]], dtype=torch.float64)
# 38
# tensor([[1.0444e+02, 3.1029e+08],
#         [3.5768e+00, 3.1031e+08],
#         [1.9192e+01, 3.1033e+08],
#         [1.0998e+02, 3.1035e+08],
#         [3.6804e+01, 3.1037e+08],
#         [1.0609e+01, 3.1039e+08],
#         [3.1537e+01, 3.1041e+08],
#         [2.4070e+00, 3.1045e+08],
#         [5.8563e+01, 3.1047e+08],
#         [2.5115e+01, 3.1049e+08]], dtype=torch.float64)
# 39
# tensor([[5.0612e+01, 3.1053e+08],
#         [5.8555e+01, 3.1057e+08],
#         [1.0860e+02, 3.1059e+08],
#         [7.3489e+01, 3.1059e+08],
#         [1.7909e+01, 3.1065e+08],
#         [5.2975e+00, 3.1069e+08],
#         [9.4000e+00, 3.1069e+08],
#         [1.0187e+01, 3.1071e+08],
#         [1.3678e+00, 3.1075e+08],
#         [6.6075e+01, 3.1077e+08]], dtype=torch.float64)
# 40
# tensor([[1.2629e+02, 3.1079e+08],
#         [2.2753e+02, 3.1079e+08],
#         [1.3769e+02, 3.1081e+08],
#         [1.7030e+02, 3.1081e+08],
#         [3.1324e+01, 3.1083e+08],
#         [3.0658e+01, 3.1085e+08],
#         [1.3858e+01, 3.1087e+08],
#         [1.7659e+01, 3.1087e+08],
#         [7.6506e+01, 3.1089e+08],
#         [5.8166e+01, 3.1089e+08]], dtype=torch.float64)
# 41
# tensor([[3.0483e+00, 3.1091e+08],
#         [6.4257e+01, 3.1093e+08],
#         [6.8575e+01, 3.1095e+08],
#         [9.5903e+00, 3.1097e+08],
#         [1.6817e+02, 3.1099e+08],
#         [1.6218e+01, 3.1105e+08],
#         [1.2133e+01, 3.1105e+08],
#         [2.2672e+01, 3.1107e+08],
#         [8.8494e+00, 3.1109e+08],
#         [5.8269e+00, 3.1109e+08]], dtype=torch.float64)
# 42
# tensor([[3.7879e+01, 3.1111e+08],
#         [1.1355e+01, 3.1113e+08],
#         [2.5430e+01, 3.1113e+08],
#         [6.6875e+00, 3.1115e+08],
#         [8.3896e+00, 3.1115e+08],
#         [3.6874e+01, 3.1119e+08],
#         [1.1881e+02, 3.1121e+08],
#         [2.6866e+01, 3.1123e+08],
#         [2.9884e+01, 3.1125e+08],
#         [4.1023e+01, 3.1125e+08]], dtype=torch.float64)
# 43
# tensor([[6.3065e+00, 3.1127e+08],
#         [9.5432e+00, 3.1127e+08],
#         [3.2496e+01, 3.1129e+08],
#         [3.9982e+00, 3.1131e+08],
#         [7.2493e+01, 3.1139e+08],
#         [1.0593e+02, 3.1141e+08],
#         [7.8144e+01, 3.1143e+08],
#         [6.0384e+01, 3.1143e+08],
#         [4.4648e+00, 3.1147e+08],
#         [7.4200e+01, 3.1153e+08]], dtype=torch.float64)
# 44
# tensor([[7.2039e+01, 3.1155e+08],
#         [4.7297e+01, 3.1155e+08],
#         [1.2833e+01, 3.1157e+08],
#         [3.1223e+01, 3.1157e+08],
#         [4.5507e+01, 3.1159e+08],
#         [1.0570e+01, 3.1161e+08],
#         [8.8491e+00, 3.1161e+08],
#         [2.8947e+01, 3.1163e+08],
#         [3.5705e+00, 3.1165e+08],
#         [3.8571e+00, 3.1165e+08]], dtype=torch.float64)
# 45
# tensor([[2.2926e+01, 3.1167e+08],
#         [2.2681e+01, 3.1167e+08],
#         [9.1934e+01, 3.1169e+08],
#         [1.6023e+00, 3.1171e+08],
#         [3.8144e+01, 3.1175e+08],
#         [4.2200e+01, 3.1175e+08],
#         [1.8521e+01, 3.1179e+08],
#         [2.1968e+01, 3.1181e+08],
#         [3.3532e+01, 3.1181e+08],
#         [3.6490e+01, 3.1183e+08]], dtype=torch.float64)
# 46
# tensor([[5.1945e+01, 3.1183e+08],
#         [1.2551e+02, 3.1185e+08],
#         [9.2579e-01, 3.2001e+08],
#         [8.9905e-01, 3.2001e+08],
#         [5.5295e+00, 3.2003e+08],
#         [5.7347e+00, 3.2003e+08],
#         [1.6575e+01, 3.2005e+08],
#         [2.0888e+00, 3.2007e+08],
#         [1.2670e+01, 3.2013e+08],
#         [2.8593e+00, 3.2017e+08]], dtype=torch.float64)
# 47
# tensor([[4.2511e-01, 3.2021e+08],
#         [1.4188e+00, 3.2021e+08],
#         [2.2243e+00, 3.2023e+08],
#         [2.0271e+00, 3.2027e+08],
#         [1.8822e+00, 3.2029e+08],
#         [2.7995e+00, 3.2031e+08],
#         [5.5981e+00, 3.2033e+08],
#         [6.1104e+00, 3.2033e+08],
#         [2.6005e+01, 3.5001e+08],
#         [1.2463e+01, 3.5005e+08]], dtype=torch.float64)
# 48
# tensor([[6.8008e-01, 3.5007e+08],
#         [6.2061e+01, 3.5009e+08],
#         [2.6189e+00, 3.5011e+08],
#         [1.2327e+01, 3.5015e+08],
#         [5.1544e+00, 3.5017e+08],
#         [6.1652e-01, 3.5019e+08],
#         [4.5623e-01, 3.5019e+08],
#         [7.8600e-01, 3.5021e+08],
#         [6.3533e-01, 3.5021e+08],
#         [8.3442e+00, 3.5023e+08]], dtype=torch.float64)
# 49
# tensor([[6.7529e+00, 3.5023e+08],
#         [2.1301e+01, 3.5025e+08],
#         [9.2381e-01, 3.5027e+08],
#         [9.9232e-01, 3.5027e+08],
#         [1.4796e+01, 3.5028e+08],
#         [9.0212e+00, 3.5029e+08],
#         [8.9044e+00, 3.5029e+08],
#         [9.8724e-01, 3.5031e+08],
#         [2.2402e-01, 3.5033e+08],
#         [1.7078e+00, 3.5037e+08]], dtype=torch.float64)
# 50
# tensor([[5.4475e-01, 3.5039e+08],
#         [2.9173e+00, 3.5043e+08],
#         [2.1450e-01, 3.5045e+08],
#         [1.8853e-01, 3.5045e+08],
#         [2.3992e-01, 3.5047e+08],
#         [5.7135e+00, 3.5049e+08],
#         [2.9766e+00, 3.5051e+08],
#         [2.5512e+00, 3.5051e+08],
#         [2.4422e+00, 3.5053e+08],
#         [2.3940e+00, 3.5053e+08]], dtype=torch.float64)
# 51
# tensor([[5.0928e+00, 3.5055e+08],
#         [8.8684e+00, 3.5057e+08],
#         [8.5627e+00, 3.5059e+08],
#         [1.7264e-01, 3.8001e+08],
#         [4.0291e-01, 3.8003e+08],
#         [2.7678e-01, 3.8003e+08],
#         [1.1105e-01, 3.8007e+08],
#         [2.3847e-01, 3.8009e+08],
#         [3.3848e-01, 3.8011e+08],
#         [1.0338e+00, 3.8015e+08]], dtype=torch.float64)
# 52
# tensor([[2.8582e+00, 3.8021e+08],
#         [8.9669e-01, 3.8025e+08],
#         [1.3441e+00, 3.8027e+08],
#         [9.5835e-02, 3.8033e+08],
#         [3.2347e+00, 3.8035e+08],
#         [3.6468e+00, 3.8035e+08],
#         [1.5036e-01, 3.8037e+08],
#         [1.7700e+00, 3.8039e+08],
#         [7.0574e-02, 3.8041e+08],
#         [7.5279e-02, 3.8041e+08]], dtype=torch.float64)
# 53
# tensor([[1.3036e+00, 3.8047e+08],
#         [1.0618e+00, 3.8047e+08],
#         [3.5807e-01, 3.8051e+08],
#         [5.9706e-01, 3.8053e+08],
#         [2.1009e+00, 3.8053e+08],
#         [6.5924e-01, 3.8055e+08],
#         [9.0417e-01, 3.8055e+08],
#         [5.1010e-01, 3.8063e+08],
#         [8.7445e-01, 3.8065e+08],
#         [6.3333e-01, 3.8067e+08]], dtype=torch.float64)
# 54
# tensor([[5.5061e-01, 3.8069e+08],
#         [5.3095e-01, 3.8069e+08],
#         [8.5723e-02, 3.8071e+08],
#         [5.9432e+00, 3.8073e+08],
#         [9.3227e+00, 3.8073e+08],
#         [3.5826e-02, 3.8075e+08],
#         [1.8413e-01, 3.8085e+08],
#         [2.2190e-01, 3.8085e+08],
#         [1.0943e-01, 3.8087e+08],
#         [8.7544e-02, 3.8087e+08]], dtype=torch.float64)
# 55
# tensor([[5.8914e-01, 3.8089e+08],
#         [1.6001e+00, 3.8091e+08],
#         [2.0270e+00, 3.8093e+08],
#         [2.3830e+00, 3.8093e+08],
#         [1.5310e-01, 3.8095e+08],
#         [3.2772e-01, 3.8099e+08],
#         [1.7189e+00, 3.8101e+08],
#         [2.1934e+00, 3.8101e+08],
#         [1.9929e+00, 3.8105e+08],
#         [3.4713e+00, 3.8105e+08]], dtype=torch.float64)
# 56
# tensor([[8.4211e-01, 4.0001e+08],
#         [8.2615e+00, 4.0007e+08],
#         [8.8017e+00, 4.0009e+08],
#         [3.1123e+00, 4.0011e+08],
#         [1.6198e+00, 4.0013e+08],
#         [2.5265e+01, 4.0015e+08],
#         [4.4653e+00, 4.0017e+08],
#         [9.6761e-01, 4.0019e+08],
#         [5.4593e-01, 4.0021e+08],
#         [6.6724e-01, 4.0021e+08]], dtype=torch.float64)
# 57
# tensor([[1.4652e+01, 4.0027e+08],
#         [1.0152e+01, 4.0027e+08],
#         [2.3185e-01, 4.0029e+08],
#         [1.6554e+00, 4.0031e+08],
#         [4.0361e-01, 4.0033e+08],
#         [4.2832e-01, 4.0033e+08],
#         [2.1295e-01, 4.0035e+08],
#         [8.4403e+00, 4.0039e+08],
#         [1.4655e+00, 4.0041e+08],
#         [2.5395e+00, 4.0043e+08]], dtype=torch.float64)
# 58
# tensor([[5.8153e+00, 4.0045e+08],
#         [3.0506e+00, 4.0047e+08],
#         [2.7166e+00, 4.0047e+08],
#         [6.8098e+00, 4.0051e+08],
#         [3.1743e+00, 4.0055e+08],
#         [2.8373e+01, 4.0057e+08],
#         [2.3563e+00, 4.0059e+08],
#         [5.8143e+00, 4.0059e+08],
#         [4.5203e-01, 4.0061e+08],
#         [7.4401e+00, 4.0065e+08]], dtype=torch.float64)
# 59
# tensor([[5.3223e-01, 4.0067e+08],
#         [2.9971e+00, 4.0069e+08],
#         [7.5077e+00, 4.0071e+08],
#         [3.9436e+00, 4.0073e+08],
#         [1.0230e+00, 4.0075e+08],
#         [1.2208e-01, 4.0077e+08],
#         [1.8751e+00, 4.0083e+08],
#         [1.5356e+00, 4.0085e+08],
#         [8.6769e+00, 4.0093e+08],
#         [2.8607e+00, 4.0095e+08]], dtype=torch.float64)
# 60
# tensor([[1.9709e+00, 4.0099e+08],
#         [2.3056e+00, 4.0099e+08],
#         [1.3353e+00, 4.0101e+08],
#         [5.3997e-01, 4.0103e+08],
#         [1.4210e-01, 4.0103e+08],
#         [8.4443e-01, 4.0107e+08],
#         [3.5951e-01, 4.0107e+08],
#         [1.7748e+01, 4.0109e+08],
#         [4.4872e-02, 4.0111e+08],
#         [5.5495e-01, 4.0113e+08]], dtype=torch.float64)
# 61
# tensor([[5.1156e-01, 4.0113e+08],
#         [3.7025e+00, 4.0115e+08],
#         [7.9689e-01, 4.0117e+08],
#         [2.3971e+00, 4.0119e+08],
#         [1.8073e+00, 4.0119e+08],
#         [1.2945e-01, 4.0121e+08],
#         [6.9920e-02, 4.0127e+08],
#         [1.6668e+00, 4.0129e+08],
#         [4.2764e-01, 4.0131e+08],
#         [6.2672e-01, 4.0131e+08]], dtype=torch.float64)
# 62
# tensor([[4.6107e-01, 4.0135e+08],
#         [8.7745e+01, 4.0139e+08],
#         [6.1283e+00, 4.0141e+08],
#         [9.7740e+00, 4.0141e+08],
#         [2.8185e+00, 4.0143e+08],
#         [4.5185e+00, 4.0143e+08],
#         [6.1903e-02, 4.0147e+08],
#         [3.4666e-01, 4.0147e+08],
#         [4.1926e+00, 4.0149e+08],
#         [6.3330e+00, 4.0153e+08]], dtype=torch.float64)
# 63
# tensor([[1.2026e+01, 4.1001e+08],
#         [8.2432e+00, 4.1001e+08],
#         [6.6477e+00, 4.1003e+08],
#         [1.8407e+01, 4.1005e+08],
#         [3.2705e-01, 4.1007e+08],
#         [3.2349e+00, 4.1009e+08],
#         [1.0120e+00, 4.1011e+08],
#         [2.6960e+00, 4.1013e+08],
#         [7.3404e-01, 4.1015e+08],
#         [8.1774e+00, 4.1017e+08]], dtype=torch.float64)
# 64
# tensor([[3.1956e-01, 4.1019e+08],
#         [4.1643e-01, 4.1019e+08],
#         [2.8303e+00, 4.1021e+08],
#         [5.5597e-01, 4.1023e+08],
#         [1.0737e+01, 4.1025e+08],
#         [3.1209e+00, 4.1027e+08],
#         [2.4878e+00, 4.1029e+08],
#         [1.2970e+01, 4.1035e+08],
#         [5.3450e+00, 4.1039e+08],
#         [3.4166e+00, 4.1045e+08]], dtype=torch.float64)
# 65
# tensor([[5.7873e+01, 4.1047e+08],
#         [8.0821e+01, 4.1047e+08],
#         [5.3245e+01, 4.1049e+08],
#         [4.1358e+00, 4.1055e+08],
#         [4.0491e+00, 4.1055e+08],
#         [2.0757e+01, 4.1059e+08],
#         [7.2412e-01, 4.1063e+08],
#         [1.1287e+01, 4.1071e+08],
#         [1.2793e+01, 4.1071e+08],
#         [2.3813e-01, 4.6003e+08]], dtype=torch.float64)
# 66
# tensor([[1.9700e+00, 4.6005e+08],
#         [1.1514e+01, 4.6007e+08],
#         [4.0557e+00, 4.6007e+08],
#         [7.6008e+00, 4.6011e+08],
#         [1.2347e+00, 4.6013e+08],
#         [3.6764e+00, 4.6013e+08],
#         [4.8369e+00, 4.6017e+08],
#         [7.3933e-01, 4.6019e+08],
#         [3.3199e-01, 4.6019e+08],
#         [7.1401e+00, 4.6021e+08]], dtype=torch.float64)
# 67
# tensor([[2.9526e+00, 4.6021e+08],
#         [8.8058e-01, 4.6023e+08],
#         [4.0180e+00, 4.6025e+08],
#         [6.5841e+00, 4.6027e+08],
#         [1.2383e+01, 4.6027e+08],
#         [7.5896e+00, 4.6029e+08],
#         [7.0143e+00, 4.6029e+08],
#         [4.7238e-01, 4.6033e+08],
#         [7.1552e-01, 4.6035e+08],
#         [5.6293e-01, 4.6037e+08]], dtype=torch.float64)
# 68
# tensor([[2.3229e+00, 4.6043e+08],
#         [1.1492e+00, 4.6045e+08],
#         [3.0921e-01, 4.6045e+08],
#         [9.5680e+00, 4.6051e+08],
#         [4.9045e+00, 4.6057e+08],
#         [1.6589e-01, 4.6059e+08],
#         [3.6490e-01, 4.6061e+08],
#         [7.1741e-02, 4.6063e+08],
#         [1.4348e-01, 4.6063e+08],
#         [3.0479e+00, 4.6065e+08]], dtype=torch.float64)
# 69
# tensor([[6.2661e-02, 4.6071e+08],
#         [7.3701e-01, 4.6073e+08],
#         [1.0581e+00, 4.6075e+08],
#         [2.5487e+00, 4.6077e+08],
#         [5.7721e+00, 4.6079e+08],
#         [4.0296e+00, 4.6081e+08],
#         [2.8287e+00, 4.6081e+08],
#         [3.6267e+00, 4.6083e+08],
#         [3.0215e-01, 4.6085e+08],
#         [1.0271e+00, 4.6087e+08]], dtype=torch.float64)
# 70
# tensor([[8.4366e-01, 4.6087e+08],
#         [1.7526e-01, 4.6089e+08],
#         [4.5208e+00, 4.6091e+08],
#         [5.4417e-01, 4.6091e+08],
#         [2.0363e-01, 4.6097e+08],
#         [3.5172e-01, 4.6097e+08],
#         [1.8335e+01, 4.6099e+08],
#         [4.0860e+00, 4.6101e+08],
#         [5.9155e+00, 4.6103e+08],
#         [1.1258e-01, 4.6105e+08]], dtype=torch.float64)
# 71
# tensor([[1.7414e+00, 4.6109e+08],
#         [3.0648e-01, 4.6111e+08],
#         [3.0648e-01, 4.6111e+08],
#         [5.7775e+00, 4.6115e+08],
#         [1.4064e+00, 4.6119e+08],
#         [8.1504e-01, 4.6119e+08],
#         [1.7784e+00, 4.6123e+08],
#         [3.2353e+00, 4.6125e+08],
#         [7.0287e+00, 4.6127e+08],
#         [8.7124e+00, 4.6127e+08]], dtype=torch.float64)
# 72
# tensor([[7.5003e-01, 4.6129e+08],
#         [6.7269e+00, 4.6135e+08],
#         [9.5488e+00, 4.6135e+08],
#         [4.5979e-02, 4.6137e+08],
#         [6.7615e-02, 4.6137e+08],
#         [4.2651e+00, 4.8001e+08],
#         [7.2628e+00, 4.8005e+08],
#         [2.9738e-01, 4.8009e+08],
#         [2.1159e-01, 4.8009e+08],
#         [2.6279e+00, 4.8011e+08]], dtype=torch.float64)
# 73
# tensor([[1.6930e+01, 4.8013e+08],
#         [1.4213e+01, 4.8013e+08],
#         [4.5716e+00, 4.8015e+08],
#         [4.1774e+01, 4.8017e+08],
#         [2.1988e+00, 4.8019e+08],
#         [1.4059e+00, 4.8023e+08],
#         [4.5156e+00, 4.8025e+08],
#         [2.6950e+00, 4.8025e+08],
#         [1.0645e+02, 4.8029e+08],
#         [1.4149e+00, 4.8031e+08]], dtype=torch.float64)
# 74
# tensor([[2.0076e+00, 4.8031e+08],
#         [2.3048e+00, 4.8035e+08],
#         [5.0945e+00, 4.8037e+08],
#         [5.2943e+01, 4.8041e+08],
#         [4.4190e+01, 4.8041e+08],
#         [6.3652e-01, 4.8049e+08],
#         [9.2944e+00, 4.8051e+08],
#         [2.9847e+00, 4.8053e+08],
#         [2.2934e+00, 4.8055e+08],
#         [8.0833e-01, 4.8057e+08]], dtype=torch.float64)
# 75
# tensor([[7.4129e-01, 4.8059e+08],
#         [4.0006e-01, 4.8059e+08],
#         [1.6347e+00, 4.8061e+08],
#         [1.3266e+00, 4.8061e+08],
#         [4.8381e+01, 4.8065e+08],
#         [4.6657e-01, 4.8067e+08],
#         [1.9181e+02, 4.8069e+08],
#         [1.3616e+02, 4.8069e+08],
#         [2.8033e+00, 4.8071e+08],
#         [3.4736e+00, 4.8073e+08]], dtype=torch.float64)
# 76
# tensor([[7.8119e+00, 4.8075e+08],
#         [1.2076e+00, 4.8077e+08],
#         [7.6242e-01, 4.8077e+08],
#         [4.1399e+01, 4.8079e+08],
#         [4.6297e+01, 4.8079e+08],
#         [3.4374e-01, 4.8081e+08],
#         [2.8966e-02, 4.8083e+08],
#         [3.7499e+00, 4.8085e+08],
#         [2.5393e+01, 4.8087e+08],
#         [1.5272e+01, 4.8091e+08]], dtype=torch.float64)
# 77
# tensor([[3.4036e+00, 4.8095e+08],
#         [2.6626e+00, 4.8097e+08],
#         [1.1886e+00, 4.8099e+08],
#         [4.1833e+01, 4.8107e+08],
#         [2.0184e+01, 4.8107e+08],
#         [1.1650e+02, 4.8111e+08],
#         [9.4543e+01, 4.8111e+08],
#         [4.2269e+01, 4.8115e+08],
#         [6.4741e+00, 4.8121e+08],
#         [4.9579e+00, 4.8123e+08]], dtype=torch.float64)
# 78
# tensor([[4.7621e+00, 4.8125e+08],
#         [1.3678e+01, 4.8129e+08],
#         [1.0714e+00, 4.8131e+08],
#         [4.0919e+00, 4.8135e+08],
#         [1.7282e-01, 4.8137e+08],
#         [8.1285e+00, 4.8141e+08],
#         [5.1557e+00, 4.8143e+08],
#         [1.3754e+00, 4.8149e+08],
#         [2.6699e+00, 4.8151e+08],
#         [4.9826e+01, 4.8153e+08]], dtype=torch.float64)
# 79
# tensor([[4.0139e+01, 4.8153e+08],
#         [1.5899e+00, 4.8155e+08],
#         [3.5749e+01, 4.8157e+08],
#         [4.3637e+01, 4.8157e+08],
#         [1.9340e+00, 4.8159e+08],
#         [2.5931e+01, 4.8163e+08],
#         [2.6038e+01, 4.8163e+08],
#         [1.0244e+02, 4.8165e+08],
#         [4.0565e+00, 4.8169e+08],
#         [3.0571e+00, 4.8171e+08]], dtype=torch.float64)
# 80
# tensor([[1.5108e+01, 4.8173e+08],
#         [1.8145e+00, 4.8175e+08],
#         [2.4582e+00, 4.8175e+08],
#         [1.3286e+01, 4.8179e+08],
#         [1.6166e+01, 4.8179e+08],
#         [6.2982e+00, 4.8181e+08],
#         [5.9622e+00, 4.8183e+08],
#         [2.3660e+00, 4.8183e+08],
#         [2.1249e+00, 4.8185e+08],
#         [4.8664e+00, 4.8187e+08]], dtype=torch.float64)
# 81
# tensor([[3.8621e+00, 4.8187e+08],
#         [9.9652e+01, 4.8189e+08],
#         [7.8070e+01, 4.8195e+08],
#         [2.3365e+00, 4.8199e+08],
#         [6.8724e+01, 4.8201e+08],
#         [1.8316e+00, 4.8203e+08],
#         [1.0995e+02, 4.8205e+08],
#         [1.8870e+01, 4.8207e+08],
#         [6.6469e+00, 4.8209e+08],
#         [3.4650e+00, 4.8211e+08]], dtype=torch.float64)
# 82
# tensor([[3.4121e+00, 4.8215e+08],
#         [5.2826e+01, 4.8219e+08],
#         [9.6905e+00, 4.8221e+08],
#         [9.4851e+00, 4.8221e+08],
#         [4.1031e+00, 4.8223e+08],
#         [2.6231e+00, 4.8223e+08],
#         [1.6032e+00, 4.8225e+08],
#         [1.2606e+00, 4.8225e+08],
#         [6.6781e+00, 4.8229e+08],
#         [8.7846e+00, 4.8229e+08]], dtype=torch.float64)
# 83
# tensor([[9.4031e-01, 4.8231e+08],
#         [3.6431e-01, 4.8235e+08],
#         [2.4984e+01, 4.8239e+08],
#         [6.3180e-01, 4.8243e+08],
#         [4.9507e-01, 4.8243e+08],
#         [6.2845e+00, 4.8245e+08],
#         [5.2406e+00, 4.8245e+08],
#         [5.3511e-01, 4.8247e+08],
#         [2.1269e+00, 4.8249e+08],
#         [3.9760e+00, 4.8251e+08]], dtype=torch.float64)
# 84
# tensor([[1.3367e+00, 4.8253e+08],
#         [5.5082e+00, 4.8255e+08],
#         [1.7297e+00, 4.8257e+08],
#         [3.4464e-01, 4.8257e+08],
#         [3.4964e+00, 4.8259e+08],
#         [2.8335e-01, 4.8261e+08],
#         [6.8358e-01, 4.8263e+08],
#         [2.3213e+00, 4.8265e+08],
#         [1.0067e+00, 4.8269e+08],
#         [1.7457e-01, 4.8269e+08]], dtype=torch.float64)
# 85
# tensor([[8.5218e-01, 4.8271e+08],
#         [1.4903e+00, 4.8271e+08],
#         [1.6301e+01, 4.8275e+08],
#         [1.6227e+01, 4.8275e+08],
#         [2.1562e+00, 4.8283e+08],
#         [3.6528e+00, 4.8283e+08],
#         [6.0479e+00, 4.8287e+08],
#         [1.8144e+00, 4.8289e+08],
#         [4.0545e+00, 4.8291e+08],
#         [1.6848e+01, 4.8295e+08]], dtype=torch.float64)
# 86
# tensor([[1.8353e+01, 4.8295e+08],
#         [1.6000e+00, 4.8297e+08],
#         [5.6953e-01, 4.8299e+08],
#         [5.9691e-01, 4.8299e+08],
#         [1.4196e-01, 4.8301e+08],
#         [5.4494e+00, 4.8309e+08],
#         [1.9294e+00, 4.8311e+08],
#         [3.8500e+00, 4.8313e+08],
#         [4.5851e-01, 4.8315e+08],
#         [1.0282e+01, 4.8321e+08]], dtype=torch.float64)
# 87
# tensor([[1.1009e+01, 4.8325e+08],
#         [7.4712e-01, 4.8327e+08],
#         [5.1769e-01, 4.8327e+08],
#         [1.3900e+00, 4.8333e+08],
#         [7.6568e+00, 4.8335e+08],
#         [1.3783e+00, 4.8337e+08],
#         [6.7509e-01, 4.8337e+08],
#         [3.5422e+01, 4.8339e+08],
#         [3.1541e+01, 4.8339e+08],
#         [1.0086e+00, 4.8343e+08]], dtype=torch.float64)
# 88
# tensor([[3.2514e+00, 4.8345e+08],
#         [4.3961e+00, 4.8345e+08],
#         [3.3838e+00, 4.8347e+08],
#         [6.2411e-01, 4.8349e+08],
#         [2.2255e-01, 4.8349e+08],
#         [1.3199e+00, 4.8351e+08],
#         [8.9465e-01, 4.8351e+08],
#         [5.4920e+00, 4.8353e+08],
#         [6.9291e+00, 4.8353e+08],
#         [4.3516e+00, 4.8355e+08]], dtype=torch.float64)
# 89
# tensor([[3.3198e+01, 4.8357e+08],
#         [4.1415e+01, 4.8357e+08],
#         [1.4412e+01, 4.8361e+08],
#         [2.1679e+00, 4.8363e+08],
#         [3.0050e-01, 4.8363e+08],
#         [3.0739e+00, 4.8365e+08],
#         [4.0784e+00, 4.8367e+08],
#         [8.4560e+01, 4.8369e+08],
#         [1.2849e+01, 4.8371e+08],
#         [2.0573e+00, 4.8375e+08]], dtype=torch.float64)
# 90
# tensor([[6.0909e-01, 4.8377e+08],
#         [5.6707e-01, 4.8379e+08],
#         [1.5072e+01, 4.8381e+08],
#         [8.3853e+00, 4.8383e+08],
#         [1.0183e+01, 4.8383e+08],
#         [5.5324e-01, 4.8385e+08],
#         [4.0167e-01, 4.8385e+08],
#         [7.9411e+00, 4.8389e+08],
#         [1.0583e+00, 4.8391e+08],
#         [1.1873e+01, 4.8393e+08]], dtype=torch.float64)
# 91
# tensor([[3.9232e+00, 4.8393e+08],
#         [5.4975e+01, 4.8395e+08],
#         [3.0389e+01, 4.8395e+08],
#         [1.6602e+00, 4.8397e+08],
#         [1.2707e+00, 4.8399e+08],
#         [4.0475e+00, 4.8401e+08],
#         [4.5979e+00, 4.8401e+08],
#         [8.9566e-01, 4.8405e+08],
#         [6.8185e+00, 4.8409e+08],
#         [1.0880e+00, 4.8411e+08]], dtype=torch.float64)
# 92
# tensor([[2.0970e+00, 4.8411e+08],
#         [9.3309e-01, 4.8413e+08],
#         [3.6228e+00, 4.8415e+08],
#         [1.4478e-01, 4.8417e+08],
#         [8.6867e-02, 4.8417e+08],
#         [2.3991e+00, 4.8419e+08],
#         [1.3005e+02, 4.8421e+08],
#         [6.9164e+00, 4.8423e+08],
#         [1.0303e+01, 4.8423e+08],
#         [5.0873e+00, 4.8425e+08]], dtype=torch.float64)
# 93
# tensor([[9.8591e-01, 4.8427e+08],
#         [5.0372e-01, 4.8427e+08],
#         [2.9433e-01, 4.8433e+08],
#         [8.8112e-01, 4.8435e+08],
#         [6.1721e+01, 4.8437e+08],
#         [6.3733e+00, 4.8439e+08],
#         [1.2473e+00, 4.8441e+08],
#         [1.6045e-01, 4.8443e+08],
#         [7.3768e+01, 4.8445e+08],
#         [4.7775e+01, 4.8445e+08]], dtype=torch.float64)
# 94
# tensor([[3.4739e-02, 4.8447e+08],
#         [9.2064e-01, 4.8449e+08],
#         [1.3488e+01, 4.8451e+08],
#         [9.3906e+00, 4.8453e+08],
#         [6.4376e-01, 4.8455e+08],
#         [3.3139e+00, 4.8459e+08],
#         [4.1611e+00, 4.8461e+08],
#         [1.8394e+01, 4.8463e+08],
#         [2.7016e+00, 4.8467e+08],
#         [2.4394e+00, 4.8467e+08]], dtype=torch.float64)
# 95
# tensor([[3.9166e+00, 4.8471e+08],
#         [2.7416e+00, 4.8471e+08],
#         [2.4752e+01, 4.8473e+08],
#         [1.4056e+01, 4.8473e+08],
#         [5.5771e+00, 4.8479e+08],
#         [5.4145e+01, 4.8481e+08],
#         [5.1586e+01, 4.8481e+08],
#         [8.7635e+00, 4.8483e+08],
#         [1.0653e+01, 4.8487e+08],
#         [5.6582e-01, 4.8489e+08]], dtype=torch.float64)
# 96
# tensor([[2.3298e-01, 4.8489e+08],
#         [6.2939e+00, 4.8491e+08],
#         [1.2482e+01, 4.8493e+08],
#         [2.0875e+00, 4.8495e+08],
#         [1.2094e+02, 4.8501e+08],
#         [1.2232e+01, 4.9001e+08],
#         [1.3612e+01, 4.9001e+08],
#         [5.1674e+00, 4.9003e+08],
#         [4.4361e+00, 4.9003e+08],
#         [2.5410e+01, 4.9005e+08]], dtype=torch.float64)
# 97
# tensor([[1.5303e+00, 4.9007e+08],
#         [2.3687e+01, 4.9011e+08],
#         [5.3108e-01, 4.9013e+08],
#         [1.8519e-01, 4.9015e+08],
#         [4.1978e-01, 4.9017e+08],
#         [4.7338e-01, 4.9019e+08],
#         [4.3275e+00, 4.9023e+08],
#         [5.1640e-01, 4.9025e+08],
#         [4.4170e-01, 4.9025e+08],
#         [1.8304e+00, 4.9029e+08]], dtype=torch.float64)
# 98
# tensor([[1.8477e+00, 4.9029e+08],
#         [1.6566e+00, 4.9031e+08],
#         [1.3228e+00, 4.9033e+08],
#         [5.1946e+01, 4.9035e+08],
#         [5.1322e+01, 4.9035e+08],
#         [2.1305e-01, 4.9037e+08],
#         [2.3917e-01, 4.9037e+08],
#         [6.1101e+00, 4.9039e+08],
#         [7.7170e+00, 4.9041e+08],
#         [4.5568e+00, 4.9043e+08]], dtype=torch.float64)
# 99
# tensor([[2.3640e+00, 4.9045e+08],
#         [2.6341e+00, 4.9045e+08],
#         [5.3976e+00, 4.9047e+08],
#         [5.1933e+00, 4.9047e+08],
#         [3.3303e+01, 4.9049e+08],
#         [8.1207e+00, 4.9053e+08],
#         [5.3998e+00, 4.9055e+08],
#         [3.3418e+00, 4.9055e+08],
#         [2.0728e+01, 4.9057e+08],
#         [5.2027e+01, 5.3001e+08]], dtype=torch.float64)
# 100
# tensor([[2.3145e+01, 5.3001e+08],
#         [3.9148e+00, 5.3003e+08],
#         [2.6286e+01, 5.3005e+08],
#         [1.8885e+01, 5.3005e+08],
#         [4.3351e+00, 5.3009e+08],
#         [4.1212e+00, 5.3017e+08],
#         [3.1483e+00, 5.3017e+08],
#         [5.1686e-01, 5.3019e+08],
#         [4.0718e+01, 5.3021e+08],
#         [5.8882e-01, 5.3023e+08]], dtype=torch.float64)
# 101
# tensor([[1.4634e+01, 5.3029e+08],
#         [1.4779e+01, 5.3029e+08],
#         [7.8523e-01, 5.3031e+08],
#         [1.8812e+01, 5.3033e+08],
#         [2.9762e+01, 5.3035e+08],
#         [2.5805e+01, 5.3035e+08],
#         [8.2688e+00, 5.3039e+08],
#         [6.2475e+00, 5.3039e+08],
#         [3.7941e+00, 5.3041e+08],
#         [3.1309e+00, 5.3041e+08]], dtype=torch.float64)
# 102
# tensor([[5.7935e+00, 5.3043e+08],
#         [3.9730e+00, 5.3045e+08],
#         [4.5689e+00, 5.3045e+08],
#         [9.4143e-01, 5.3049e+08],
#         [2.8374e+01, 5.3053e+08],
#         [2.7040e+00, 5.3055e+08],
#         [5.4869e+00, 5.3057e+08],
#         [3.5222e-01, 5.3059e+08],
#         [5.3616e+00, 5.3061e+08],
#         [2.7503e+00, 5.3065e+08]], dtype=torch.float64)
# 103
# tensor([[2.5529e+00, 5.3065e+08],
#         [4.0450e-01, 5.3069e+08],
#         [3.8611e-01, 5.3069e+08],
#         [2.1489e+01, 5.3071e+08],
#         [9.4931e+00, 5.3073e+08],
#         [1.6072e+01, 5.3077e+08],
#         [5.4029e-01, 5.6001e+08],
#         [8.9842e-01, 5.6001e+08],
#         [6.9043e-01, 5.6003e+08],
#         [9.7065e-01, 5.6003e+08]], dtype=torch.float64)
# 104
# tensor([[3.0748e-01, 5.6007e+08],
#         [4.2136e-01, 5.6007e+08],
#         [1.1506e+00, 5.6009e+08],
#         [1.6451e+00, 5.6011e+08],
#         [2.3283e+01, 5.6015e+08],
#         [3.9093e+01, 5.6015e+08],
#         [7.8654e-01, 5.6017e+08],
#         [6.2976e-01, 5.6017e+08],
#         [2.5714e+01, 5.6021e+08],
#         [9.4832e-01, 5.6023e+08]], dtype=torch.float64)
# 105
# tensor([[1.7345e+00, 5.6023e+08],
#         [1.1536e-01, 5.6029e+08],
#         [4.4311e-02, 5.6029e+08],
#         [1.5057e+01, 5.6031e+08],
#         [2.0603e+00, 5.6035e+08],
#         [7.2631e-01, 5.6037e+08],
#         [6.8521e-01, 5.6039e+08],
#         [1.9498e+00, 5.6043e+08],
#         [4.1617e-01, 5.6045e+08]], dtype=torch.float64)

# %%
sample_arr = sample[['total_gw_observed', 'fips_years']].to_numpy()
sample_arr = torch.from_numpy(sample_arr)
print(type(sample_arr))
sampler = DistributedSampler(sample_arr, num_replicas=1, rank=0, shuffle=False, drop_last=False)
dataloader = DataLoader(sample_arr, batch_size=10, pin_memory=False, num_workers=1, drop_last=False, shuffle=False, 
                        sampler=sampler)
i = 0    
for item in dataloader:
    i+=1
    print(i)
    print(item)
# Out:
# <class 'torch.Tensor'>
# 1
# tensor([[2.0362e+01, 4.0032e+07],
#         [6.0970e-01, 4.0052e+07],
#         [5.1843e-01, 4.0052e+07],
#         [3.9939e+00, 4.0152e+07],
#         [2.8653e+00, 4.0172e+07],
#         [1.5500e+01, 4.0192e+07],
#         [7.4625e+00, 4.0232e+07],
#         [5.6568e+00, 4.0232e+07],
#         [4.7596e+00, 4.0252e+07],
#         [1.7401e+01, 4.0272e+07]], dtype=torch.float64)
# 2
# tensor([[1.1953e+01, 4.0272e+07],
#         [2.0021e+01, 6.0012e+07],
#         [7.5868e-02, 6.0032e+07],
#         [4.7521e+00, 6.0032e+07],
#         [6.4544e+00, 6.0052e+07],
#         [1.4558e+01, 6.0052e+07],
#         [8.8757e+01, 6.0072e+07],
#         [2.3119e+02, 6.0072e+07],
#         [1.6036e+00, 6.0092e+07],
#         [5.7174e+01, 6.0112e+07]], dtype=torch.float64)
# 3
# tensor([[2.7987e+02, 6.0112e+07],
#         [1.9883e+01, 6.0132e+07],
#         [7.6682e+00, 6.0172e+07],
#         [8.7966e+01, 6.0212e+07],
#         [1.5501e+02, 6.0252e+07],
#         [2.0566e+00, 6.0272e+07],
#         [6.1271e+01, 6.0292e+07],
#         [1.0199e+02, 6.0292e+07],
#         [1.9906e+02, 6.0312e+07],
#         [7.3576e+00, 6.0352e+07]], dtype=torch.float64)
# 4
# tensor([[9.9739e+01, 6.0372e+07],
#         [1.8585e+02, 6.0392e+07],
#         [7.8342e+00, 6.0412e+07],
#         [2.7822e+01, 6.0412e+07],
#         [1.8893e+02, 6.0472e+07],
#         [1.4879e+01, 6.0492e+07],
#         [6.8756e+00, 6.0512e+07],
#         [5.5673e+00, 6.0572e+07],
#         [2.1269e+01, 6.0572e+07],
#         [1.9832e+02, 6.0592e+07]], dtype=torch.float64)
# 5
# tensor([[1.9365e+02, 6.0592e+07],
#         [1.0859e+01, 6.0612e+07],
#         [3.3202e+01, 6.0612e+07],
#         [1.4744e+01, 6.0632e+07],
#         [3.2363e+01, 6.0652e+07],
#         [1.2840e+01, 6.0732e+07],
#         [2.0095e+01, 6.0752e+07],
#         [2.6452e+01, 6.0752e+07],
#         [1.9860e+02, 6.0772e+07],
#         [2.6965e+02, 6.0772e+07]], dtype=torch.float64)
# 6
# tensor([[2.8704e+01, 6.0792e+07],
#         [1.1835e+01, 6.0792e+07],
#         [1.3025e+01, 6.0812e+07],
#         [2.4927e+01, 6.0812e+07],
#         [3.7881e+01, 6.0832e+07],
#         [3.4453e+01, 6.0852e+07],
#         [4.6469e+01, 6.0872e+07],
#         [7.2022e+00, 6.0912e+07],
#         [9.1939e+00, 6.0912e+07],
#         [1.1953e+01, 6.0932e+07]], dtype=torch.float64)
# 7
# tensor([[1.1815e+01, 6.0932e+07],
#         [1.2922e+02, 6.0952e+07],
#         [1.6782e+02, 6.0952e+07],
#         [2.3254e+02, 6.0992e+07],
#         [3.9890e+02, 6.1012e+07],
#         [1.3390e+00, 6.1052e+07],
#         [1.3866e+02, 6.1072e+07],
#         [1.3360e+02, 6.1072e+07],
#         [9.8773e-01, 6.1092e+07],
#         [6.3988e+01, 6.1112e+07]], dtype=torch.float64)
# 8
# tensor([[1.8356e+02, 6.1152e+07],
#         [1.3352e+01, 8.0012e+07],
#         [7.9299e+00, 8.0012e+07],
#         [6.5137e+01, 8.0032e+07],
#         [7.7613e+00, 8.0052e+07],
#         [4.8823e-01, 8.0072e+07],
#         [2.0466e+01, 8.0092e+07],
#         [5.9838e-01, 8.0132e+07],
#         [4.1093e-01, 8.0132e+07],
#         [1.0778e+00, 8.0152e+07]], dtype=torch.float64)
# 9
# tensor([[1.0245e+01, 8.0172e+07],
#         [6.6023e-01, 8.0192e+07],
#         [2.5132e+01, 8.0212e+07],
#         [1.5242e+01, 8.0232e+07],
#         [3.9693e-01, 8.0272e+07],
#         [4.8936e+00, 8.0312e+07],
#         [1.6988e+01, 8.0352e+07],
#         [1.5639e+00, 8.0372e+07],
#         [1.5202e+00, 8.0392e+07],
#         [1.9730e+00, 8.0392e+07]], dtype=torch.float64)
# 10
# tensor([[5.9807e+00, 8.0412e+07],
#         [5.0123e-01, 8.0432e+07],
#         [4.9079e-01, 8.0432e+07],
#         [7.2867e-01, 8.0452e+07],
#         [2.5225e+00, 8.0472e+07],
#         [3.7403e-01, 8.0492e+07],
#         [7.0871e-01, 8.0512e+07],
#         [6.0748e-01, 8.0532e+07],
#         [1.0534e-01, 8.0572e+07],
#         [4.5661e+00, 8.0592e+07]], dtype=torch.float64)
# 11
# tensor([[3.2211e+00, 8.0592e+07],
#         [6.4225e-01, 8.0612e+07],
#         [2.7968e+00, 8.0652e+07],
#         [7.8755e+00, 8.0652e+07],
#         [6.5544e-01, 8.0672e+07],
#         [5.4254e-01, 8.0672e+07],
#         [3.2433e-01, 8.0692e+07],
#         [1.3191e-01, 8.0712e+07],
#         [7.1606e-01, 8.0732e+07],
#         [9.8845e-01, 8.0732e+07]], dtype=torch.float64)
# 12
# tensor([[1.6964e+01, 8.0752e+07],
#         [1.8925e+01, 8.0752e+07],
#         [4.3145e-01, 8.0792e+07],
#         [2.1874e-01, 8.0812e+07],
#         [9.9837e-02, 8.0812e+07],
#         [1.9051e-01, 8.0832e+07],
#         [3.2548e-01, 8.0852e+07],
#         [5.2390e-01, 8.0932e+07],
#         [7.1824e-01, 8.0972e+07],
#         [2.1320e+00, 8.1012e+07]], dtype=torch.float64)
# 13
# tensor([[3.5385e-01, 8.1032e+07],
#         [3.5881e-01, 8.1032e+07],
#         [6.1842e+01, 8.1052e+07],
#         [2.8384e-01, 8.1072e+07],
#         [1.7346e-01, 8.1072e+07],
#         [4.1197e-02, 8.1112e+07],
#         [2.8118e-01, 8.1132e+07],
#         [1.5350e+01, 8.1152e+07],
#         [3.8554e+01, 8.1152e+07],
#         [2.7582e+00, 8.1172e+07]], dtype=torch.float64)
# 14
# tensor([[1.6621e+00, 8.1192e+07],
#         [2.7003e+00, 8.1232e+07],
#         [4.7613e+00, 8.1232e+07],
#         [4.8436e+01, 8.1252e+07],
#         [5.0209e+01, 1.6001e+08],
#         [5.6049e+01, 1.6001e+08],
#         [7.5283e-01, 1.6003e+08],
#         [2.8063e+01, 1.6005e+08],
#         [1.8085e+00, 1.6007e+08],
#         [1.2102e+02, 1.6011e+08]], dtype=torch.float64)
# 15
# tensor([[1.1094e+02, 1.6011e+08],
#         [8.5457e+00, 1.6013e+08],
#         [2.2542e-01, 1.6015e+08],
#         [3.3514e+00, 1.6017e+08],
#         [1.5636e+01, 1.6021e+08],
#         [1.9797e+01, 1.6023e+08],
#         [2.4019e+01, 1.6023e+08],
#         [4.8265e+01, 1.6025e+08],
#         [9.3113e+01, 1.6025e+08],
#         [1.8049e+02, 1.6027e+08]], dtype=torch.float64)
# 16
# tensor([[2.3298e+02, 1.6027e+08],
#         [1.2678e+01, 1.6029e+08],
#         [9.8840e+01, 1.6031e+08],
#         [1.1994e+02, 1.6031e+08],
#         [1.0587e+01, 1.6033e+08],
#         [1.6158e+01, 1.6039e+08],
#         [1.7239e+01, 1.6039e+08],
#         [2.9628e+01, 1.6041e+08],
#         [7.6917e+00, 1.6045e+08],
#         [8.6485e+01, 1.6047e+08]], dtype=torch.float64)
# 17
# tensor([[1.9088e+02, 1.6051e+08],
#         [1.5149e+02, 1.6051e+08],
#         [6.9857e+01, 1.6053e+08],
#         [7.3527e+01, 1.6053e+08],
#         [1.5209e+01, 1.6055e+08],
#         [4.6383e+00, 1.6057e+08],
#         [5.9568e+01, 1.6057e+08],
#         [4.7944e+01, 1.6063e+08],
#         [1.2633e+02, 1.6065e+08],
#         [9.3325e+00, 1.6069e+08]], dtype=torch.float64)
# 18
# tensor([[3.4632e+01, 1.6071e+08],
#         [6.2581e+00, 1.6073e+08],
#         [6.1474e+01, 1.6075e+08],
#         [1.0327e+02, 1.6077e+08],
#         [1.2902e+02, 1.6077e+08],
#         [3.8558e-01, 1.6079e+08],
#         [5.4052e+01, 1.6081e+08],
#         [8.9624e+01, 1.6083e+08],
#         [4.7073e-01, 1.6085e+08],
#         [4.8783e-01, 2.0001e+08]], dtype=torch.float64)
# 19
# tensor([[8.3034e-02, 2.0001e+08],
#         [2.1626e+01, 2.0009e+08],
#         [2.1455e+01, 2.0009e+08],
#         [2.4578e-02, 2.0011e+08],
#         [0.0000e+00, 2.0011e+08],
#         [1.6715e+00, 2.0013e+08],
#         [8.3808e-01, 2.0015e+08],
#         [7.1808e-01, 2.0017e+08],
#         [2.2377e+01, 2.0023e+08],
#         [2.6414e+01, 2.0023e+08]], dtype=torch.float64)
# 20
# tensor([[2.8255e+00, 2.0025e+08],
#         [7.1183e+00, 2.0027e+08],
#         [6.4253e-02, 2.0031e+08],
#         [4.1609e+00, 2.0037e+08],
#         [4.3280e+00, 2.0037e+08],
#         [6.1989e+00, 2.0039e+08],
#         [3.1598e+00, 2.0041e+08],
#         [3.2837e+00, 2.0041e+08],
#         [1.0672e+00, 2.0043e+08],
#         [3.2281e+00, 2.0045e+08]], dtype=torch.float64)
# 21
# tensor([[8.5940e+01, 2.0047e+08],
#         [0.0000e+00, 2.0049e+08],
#         [1.2807e+00, 2.0053e+08],
#         [1.1489e+02, 2.0055e+08],
#         [9.4410e+01, 2.0055e+08],
#         [4.6583e+01, 2.0057e+08],
#         [6.6356e-01, 2.0059e+08],
#         [5.8175e-01, 2.0059e+08],
#         [1.4683e+01, 2.0061e+08],
#         [1.0527e+01, 2.0061e+08]], dtype=torch.float64)
# 22
# tensor([[8.4185e+00, 2.0065e+08],
#         [9.3536e+01, 2.0067e+08],
#         [8.1394e+01, 2.0069e+08],
#         [1.8260e-02, 2.0073e+08],
#         [2.2825e-02, 2.0073e+08],
#         [1.9663e+01, 2.0075e+08],
#         [2.3125e+00, 2.0077e+08],
#         [1.9962e+00, 2.0077e+08],
#         [1.8291e+02, 2.0081e+08],
#         [1.3085e+02, 2.0081e+08]], dtype=torch.float64)
# 23
# tensor([[3.2532e+00, 2.0087e+08],
#         [2.2442e+00, 2.0087e+08],
#         [1.1870e+00, 2.0089e+08],
#         [1.0315e+01, 2.0091e+08],
#         [7.9877e+01, 2.0093e+08],
#         [1.1031e+01, 2.0095e+08],
#         [1.0378e+01, 2.0095e+08],
#         [4.3664e+01, 2.0097e+08],
#         [0.0000e+00, 2.0099e+08],
#         [1.1431e+01, 2.0101e+08]], dtype=torch.float64)
# 24
# tensor([[5.6483e+00, 2.0103e+08],
#         [4.4627e+00, 2.0103e+08],
#         [7.2745e-01, 2.0105e+08],
#         [3.3395e+00, 2.0109e+08],
#         [1.7952e+01, 2.0113e+08],
#         [1.8339e+01, 2.0113e+08],
#         [1.1998e+00, 2.0117e+08],
#         [7.0977e+01, 2.0119e+08],
#         [2.6621e-02, 2.0121e+08],
#         [2.6621e-02, 2.0121e+08]], dtype=torch.float64)
# 25
# tensor([[6.4041e-01, 2.0123e+08],
#         [7.2533e-02, 2.0125e+08],
#         [3.3743e-01, 2.0127e+08],
#         [3.5993e-01, 2.0127e+08],
#         [3.4818e+01, 2.0129e+08],
#         [0.0000e+00, 2.0133e+08],
#         [6.2533e+00, 2.0137e+08],
#         [7.7126e+00, 2.0137e+08],
#         [7.2994e-03, 2.0139e+08],
#         [3.2172e+00, 2.0143e+08]], dtype=torch.float64)
# 26
# tensor([[5.0018e+01, 2.0145e+08],
#         [4.5090e+01, 2.0145e+08],
#         [3.8748e+00, 2.0147e+08],
#         [6.2665e+01, 2.0151e+08],
#         [7.0358e+00, 2.0153e+08],
#         [2.6016e+01, 2.0155e+08],
#         [4.3570e+00, 2.0161e+08],
#         [1.6540e+00, 2.0163e+08],
#         [1.7666e+00, 2.0163e+08],
#         [6.5580e+00, 2.0165e+08]], dtype=torch.float64)
# 27
# tensor([[7.5413e+00, 2.0165e+08],
#         [1.0019e-01, 2.0167e+08],
#         [3.2413e+01, 2.0171e+08],
#         [1.9250e+01, 2.0173e+08],
#         [1.3081e+02, 2.0175e+08],
#         [9.2483e+00, 2.0177e+08],
#         [6.3452e+00, 2.0177e+08],
#         [3.7646e+01, 2.0179e+08],
#         [1.2001e+00, 2.0183e+08],
#         [1.7026e+00, 2.0183e+08]], dtype=torch.float64)
# 28
# tensor([[5.7370e+01, 2.0185e+08],
#         [8.8888e+01, 2.0187e+08],
#         [1.4459e+02, 2.0189e+08],
#         [4.0822e+01, 2.0193e+08],
#         [4.2561e+01, 2.0193e+08],
#         [3.5193e+00, 2.0195e+08],
#         [1.6123e+00, 2.0197e+08],
#         [1.3227e+00, 2.0197e+08],
#         [2.6390e+01, 2.0199e+08],
#         [2.1510e+01, 2.0199e+08]], dtype=torch.float64)
# 29
# tensor([[2.6322e+00, 2.0201e+08],
#         [2.9769e+01, 2.0203e+08],
#         [1.3654e+01, 2.0209e+08],
#         [4.1092e-01, 3.0001e+08],
#         [6.8591e-01, 3.0003e+08],
#         [3.0521e-01, 3.0003e+08],
#         [1.4958e+00, 3.0007e+08],
#         [6.2507e-01, 3.0009e+08],
#         [2.5512e-02, 3.0011e+08],
#         [1.1162e-01, 3.0011e+08]], dtype=torch.float64)
# 30
# tensor([[7.7726e-01, 3.0013e+08],
#         [2.2484e-01, 3.0015e+08],
#         [7.1865e-01, 3.0019e+08],
#         [3.7413e-01, 3.0021e+08],
#         [2.6660e-01, 3.0021e+08],
#         [2.0830e+00, 3.0023e+08],
#         [3.7506e-01, 3.0025e+08],
#         [4.0645e-01, 3.0027e+08],
#         [3.4646e-01, 3.0027e+08],
#         [2.4180e+00, 3.0029e+08]], dtype=torch.float64)
# 31
# tensor([[4.2430e+00, 3.0031e+08],
#         [7.3730e-02, 3.0033e+08],
#         [3.6771e-01, 3.0035e+08],
#         [2.0215e-01, 3.0035e+08],
#         [1.7382e-01, 3.0039e+08],
#         [2.5173e-01, 3.0041e+08],
#         [7.6011e-01, 3.0043e+08],
#         [3.4969e-01, 3.0045e+08],
#         [3.6185e+00, 3.0047e+08],
#         [1.7799e+00, 3.0049e+08]], dtype=torch.float64)
# 32
# tensor([[1.1240e+00, 3.0049e+08],
#         [1.4322e-01, 3.0051e+08],
#         [7.7120e-02, 3.0051e+08],
#         [2.8780e-01, 3.0053e+08],
#         [4.5743e-01, 3.0057e+08],
#         [4.7912e-01, 3.0059e+08],
#         [1.5749e-01, 3.0059e+08],
#         [1.3470e+00, 3.0061e+08],
#         [2.8834e-01, 3.0061e+08],
#         [7.8199e+00, 3.0063e+08]], dtype=torch.float64)
# 33
# tensor([[7.9106e+00, 3.0063e+08],
#         [3.8720e-01, 3.0065e+08],
#         [8.7475e-01, 3.0067e+08],
#         [6.8015e-01, 3.0067e+08],
#         [6.3681e-02, 3.0069e+08],
#         [5.2795e-01, 3.0071e+08],
#         [1.9235e-01, 3.0071e+08],
#         [3.3893e-01, 3.0073e+08],
#         [2.7349e-01, 3.0075e+08],
#         [3.3823e-01, 3.0075e+08]], dtype=torch.float64)
# 34
# tensor([[7.3213e-01, 3.0079e+08],
#         [2.6651e-01, 3.0079e+08],
#         [6.8278e-01, 3.0083e+08],
#         [8.8771e-01, 3.0085e+08],
#         [2.8782e-01, 3.0087e+08],
#         [1.1887e+00, 3.0089e+08],
#         [3.9811e-01, 3.0089e+08],
#         [1.9023e+00, 3.0091e+08],
#         [2.3719e+00, 3.0093e+08],
#         [5.3036e-01, 3.0093e+08]], dtype=torch.float64)
# 35
# tensor([[1.2411e+00, 3.0095e+08],
#         [6.7508e-01, 3.0095e+08],
#         [4.4841e-01, 3.0097e+08],
#         [3.3417e-01, 3.0097e+08],
#         [5.2285e-01, 3.0099e+08],
#         [4.6917e-01, 3.0101e+08],
#         [6.4457e-01, 3.0103e+08],
#         [5.7464e-01, 3.0105e+08],
#         [1.3419e+00, 3.0107e+08],
#         [4.7713e-01, 3.0107e+08]], dtype=torch.float64)
# 36
# tensor([[1.5192e+00, 3.0111e+08],
#         [1.5229e+02, 3.1001e+08],
#         [4.9977e+01, 3.1003e+08],
#         [3.9921e+00, 3.1005e+08],
#         [1.0399e+01, 3.1009e+08],
#         [4.6161e+01, 3.1011e+08],
#         [7.0971e+01, 3.1011e+08],
#         [4.4460e+01, 3.1013e+08],
#         [8.7565e+00, 3.1015e+08],
#         [8.5812e+00, 3.1015e+08]], dtype=torch.float64)
# 37
# tensor([[1.7846e+01, 3.1017e+08],
#         [1.1487e+02, 3.1019e+08],
#         [1.1179e+01, 3.1021e+08],
#         [2.7904e+01, 3.1021e+08],
#         [4.5611e+01, 3.1023e+08],
#         [2.9001e+01, 3.1023e+08],
#         [1.5338e+01, 3.1025e+08],
#         [1.3932e+01, 3.1025e+08],
#         [1.9779e+01, 3.1027e+08],
#         [4.7020e+01, 3.1027e+08]], dtype=torch.float64)
# 38
# tensor([[1.0444e+02, 3.1029e+08],
#         [3.5768e+00, 3.1031e+08],
#         [1.9192e+01, 3.1033e+08],
#         [1.0998e+02, 3.1035e+08],
#         [3.6804e+01, 3.1037e+08],
#         [1.0609e+01, 3.1039e+08],
#         [3.1537e+01, 3.1041e+08],
#         [2.4070e+00, 3.1045e+08],
#         [5.8563e+01, 3.1047e+08],
#         [2.5115e+01, 3.1049e+08]], dtype=torch.float64)
# 39
# tensor([[5.0612e+01, 3.1053e+08],
#         [5.8555e+01, 3.1057e+08],
#         [1.0860e+02, 3.1059e+08],
#         [7.3489e+01, 3.1059e+08],
#         [1.7909e+01, 3.1065e+08],
#         [5.2975e+00, 3.1069e+08],
#         [9.4000e+00, 3.1069e+08],
#         [1.0187e+01, 3.1071e+08],
#         [1.3678e+00, 3.1075e+08],
#         [6.6075e+01, 3.1077e+08]], dtype=torch.float64)
# 40
# tensor([[1.2629e+02, 3.1079e+08],
#         [2.2753e+02, 3.1079e+08],
#         [1.3769e+02, 3.1081e+08],
#         [1.7030e+02, 3.1081e+08],
#         [3.1324e+01, 3.1083e+08],
#         [3.0658e+01, 3.1085e+08],
#         [1.3858e+01, 3.1087e+08],
#         [1.7659e+01, 3.1087e+08],
#         [7.6506e+01, 3.1089e+08],
#         [5.8166e+01, 3.1089e+08]], dtype=torch.float64)
# 41
# tensor([[3.0483e+00, 3.1091e+08],
#         [6.4257e+01, 3.1093e+08],
#         [6.8575e+01, 3.1095e+08],
#         [9.5903e+00, 3.1097e+08],
#         [1.6817e+02, 3.1099e+08],
#         [1.6218e+01, 3.1105e+08],
#         [1.2133e+01, 3.1105e+08],
#         [2.2672e+01, 3.1107e+08],
#         [8.8494e+00, 3.1109e+08],
#         [5.8269e+00, 3.1109e+08]], dtype=torch.float64)
# 42
# tensor([[3.7879e+01, 3.1111e+08],
#         [1.1355e+01, 3.1113e+08],
#         [2.5430e+01, 3.1113e+08],
#         [6.6875e+00, 3.1115e+08],
#         [8.3896e+00, 3.1115e+08],
#         [3.6874e+01, 3.1119e+08],
#         [1.1881e+02, 3.1121e+08],
#         [2.6866e+01, 3.1123e+08],
#         [2.9884e+01, 3.1125e+08],
#         [4.1023e+01, 3.1125e+08]], dtype=torch.float64)
# 43
# tensor([[6.3065e+00, 3.1127e+08],
#         [9.5432e+00, 3.1127e+08],
#         [3.2496e+01, 3.1129e+08],
#         [3.9982e+00, 3.1131e+08],
#         [7.2493e+01, 3.1139e+08],
#         [1.0593e+02, 3.1141e+08],
#         [7.8144e+01, 3.1143e+08],
#         [6.0384e+01, 3.1143e+08],
#         [4.4648e+00, 3.1147e+08],
#         [7.4200e+01, 3.1153e+08]], dtype=torch.float64)
# 44
# tensor([[7.2039e+01, 3.1155e+08],
#         [4.7297e+01, 3.1155e+08],
#         [1.2833e+01, 3.1157e+08],
#         [3.1223e+01, 3.1157e+08],
#         [4.5507e+01, 3.1159e+08],
#         [1.0570e+01, 3.1161e+08],
#         [8.8491e+00, 3.1161e+08],
#         [2.8947e+01, 3.1163e+08],
#         [3.5705e+00, 3.1165e+08],
#         [3.8571e+00, 3.1165e+08]], dtype=torch.float64)
# 45
# tensor([[2.2926e+01, 3.1167e+08],
#         [2.2681e+01, 3.1167e+08],
#         [9.1934e+01, 3.1169e+08],
#         [1.6023e+00, 3.1171e+08],
#         [3.8144e+01, 3.1175e+08],
#         [4.2200e+01, 3.1175e+08],
#         [1.8521e+01, 3.1179e+08],
#         [2.1968e+01, 3.1181e+08],
#         [3.3532e+01, 3.1181e+08],
#         [3.6490e+01, 3.1183e+08]], dtype=torch.float64)
# 46
# tensor([[5.1945e+01, 3.1183e+08],
#         [1.2551e+02, 3.1185e+08],
#         [9.2579e-01, 3.2001e+08],
#         [8.9905e-01, 3.2001e+08],
#         [5.5295e+00, 3.2003e+08],
#         [5.7347e+00, 3.2003e+08],
#         [1.6575e+01, 3.2005e+08],
#         [2.0888e+00, 3.2007e+08],
#         [1.2670e+01, 3.2013e+08],
#         [2.8593e+00, 3.2017e+08]], dtype=torch.float64)
# 47
# tensor([[4.2511e-01, 3.2021e+08],
#         [1.4188e+00, 3.2021e+08],
#         [2.2243e+00, 3.2023e+08],
#         [2.0271e+00, 3.2027e+08],
#         [1.8822e+00, 3.2029e+08],
#         [2.7995e+00, 3.2031e+08],
#         [5.5981e+00, 3.2033e+08],
#         [6.1104e+00, 3.2033e+08],
#         [2.6005e+01, 3.5001e+08],
#         [1.2463e+01, 3.5005e+08]], dtype=torch.float64)
# 48
# tensor([[6.8008e-01, 3.5007e+08],
#         [6.2061e+01, 3.5009e+08],
#         [2.6189e+00, 3.5011e+08],
#         [1.2327e+01, 3.5015e+08],
#         [5.1544e+00, 3.5017e+08],
#         [6.1652e-01, 3.5019e+08],
#         [4.5623e-01, 3.5019e+08],
#         [7.8600e-01, 3.5021e+08],
#         [6.3533e-01, 3.5021e+08],
#         [8.3442e+00, 3.5023e+08]], dtype=torch.float64)
# 49
# tensor([[6.7529e+00, 3.5023e+08],
#         [2.1301e+01, 3.5025e+08],
#         [9.2381e-01, 3.5027e+08],
#         [9.9232e-01, 3.5027e+08],
#         [1.4796e+01, 3.5028e+08],
#         [9.0212e+00, 3.5029e+08],
#         [8.9044e+00, 3.5029e+08],
#         [9.8724e-01, 3.5031e+08],
#         [2.2402e-01, 3.5033e+08],
#         [1.7078e+00, 3.5037e+08]], dtype=torch.float64)
# 50
# tensor([[5.4475e-01, 3.5039e+08],
#         [2.9173e+00, 3.5043e+08],
#         [2.1450e-01, 3.5045e+08],
#         [1.8853e-01, 3.5045e+08],
#         [2.3992e-01, 3.5047e+08],
#         [5.7135e+00, 3.5049e+08],
#         [2.9766e+00, 3.5051e+08],
#         [2.5512e+00, 3.5051e+08],
#         [2.4422e+00, 3.5053e+08],
#         [2.3940e+00, 3.5053e+08]], dtype=torch.float64)
# 51
# tensor([[5.0928e+00, 3.5055e+08],
#         [8.8684e+00, 3.5057e+08],
#         [8.5627e+00, 3.5059e+08],
#         [1.7264e-01, 3.8001e+08],
#         [4.0291e-01, 3.8003e+08],
#         [2.7678e-01, 3.8003e+08],
#         [1.1105e-01, 3.8007e+08],
#         [2.3847e-01, 3.8009e+08],
#         [3.3848e-01, 3.8011e+08],
#         [1.0338e+00, 3.8015e+08]], dtype=torch.float64)
# 52
# tensor([[2.8582e+00, 3.8021e+08],
#         [8.9669e-01, 3.8025e+08],
#         [1.3441e+00, 3.8027e+08],
#         [9.5835e-02, 3.8033e+08],
#         [3.2347e+00, 3.8035e+08],
#         [3.6468e+00, 3.8035e+08],
#         [1.5036e-01, 3.8037e+08],
#         [1.7700e+00, 3.8039e+08],
#         [7.0574e-02, 3.8041e+08],
#         [7.5279e-02, 3.8041e+08]], dtype=torch.float64)
# 53
# tensor([[1.3036e+00, 3.8047e+08],
#         [1.0618e+00, 3.8047e+08],
#         [3.5807e-01, 3.8051e+08],
#         [5.9706e-01, 3.8053e+08],
#         [2.1009e+00, 3.8053e+08],
#         [6.5924e-01, 3.8055e+08],
#         [9.0417e-01, 3.8055e+08],
#         [5.1010e-01, 3.8063e+08],
#         [8.7445e-01, 3.8065e+08],
#         [6.3333e-01, 3.8067e+08]], dtype=torch.float64)
# 54
# tensor([[5.5061e-01, 3.8069e+08],
#         [5.3095e-01, 3.8069e+08],
#         [8.5723e-02, 3.8071e+08],
#         [5.9432e+00, 3.8073e+08],
#         [9.3227e+00, 3.8073e+08],
#         [3.5826e-02, 3.8075e+08],
#         [1.8413e-01, 3.8085e+08],
#         [2.2190e-01, 3.8085e+08],
#         [1.0943e-01, 3.8087e+08],
#         [8.7544e-02, 3.8087e+08]], dtype=torch.float64)
# 55
# tensor([[5.8914e-01, 3.8089e+08],
#         [1.6001e+00, 3.8091e+08],
#         [2.0270e+00, 3.8093e+08],
#         [2.3830e+00, 3.8093e+08],
#         [1.5310e-01, 3.8095e+08],
#         [3.2772e-01, 3.8099e+08],
#         [1.7189e+00, 3.8101e+08],
#         [2.1934e+00, 3.8101e+08],
#         [1.9929e+00, 3.8105e+08],
#         [3.4713e+00, 3.8105e+08]], dtype=torch.float64)
# 56
# tensor([[8.4211e-01, 4.0001e+08],
#         [8.2615e+00, 4.0007e+08],
#         [8.8017e+00, 4.0009e+08],
#         [3.1123e+00, 4.0011e+08],
#         [1.6198e+00, 4.0013e+08],
#         [2.5265e+01, 4.0015e+08],
#         [4.4653e+00, 4.0017e+08],
#         [9.6761e-01, 4.0019e+08],
#         [5.4593e-01, 4.0021e+08],
#         [6.6724e-01, 4.0021e+08]], dtype=torch.float64)
# 57
# tensor([[1.4652e+01, 4.0027e+08],
#         [1.0152e+01, 4.0027e+08],
#         [2.3185e-01, 4.0029e+08],
#         [1.6554e+00, 4.0031e+08],
#         [4.0361e-01, 4.0033e+08],
#         [4.2832e-01, 4.0033e+08],
#         [2.1295e-01, 4.0035e+08],
#         [8.4403e+00, 4.0039e+08],
#         [1.4655e+00, 4.0041e+08],
#         [2.5395e+00, 4.0043e+08]], dtype=torch.float64)
# 58
# tensor([[5.8153e+00, 4.0045e+08],
#         [3.0506e+00, 4.0047e+08],
#         [2.7166e+00, 4.0047e+08],
#         [6.8098e+00, 4.0051e+08],
#         [3.1743e+00, 4.0055e+08],
#         [2.8373e+01, 4.0057e+08],
#         [2.3563e+00, 4.0059e+08],
#         [5.8143e+00, 4.0059e+08],
#         [4.5203e-01, 4.0061e+08],
#         [7.4401e+00, 4.0065e+08]], dtype=torch.float64)
# 59
# tensor([[5.3223e-01, 4.0067e+08],
#         [2.9971e+00, 4.0069e+08],
#         [7.5077e+00, 4.0071e+08],
#         [3.9436e+00, 4.0073e+08],
#         [1.0230e+00, 4.0075e+08],
#         [1.2208e-01, 4.0077e+08],
#         [1.8751e+00, 4.0083e+08],
#         [1.5356e+00, 4.0085e+08],
#         [8.6769e+00, 4.0093e+08],
#         [2.8607e+00, 4.0095e+08]], dtype=torch.float64)
# 60
# tensor([[1.9709e+00, 4.0099e+08],
#         [2.3056e+00, 4.0099e+08],
#         [1.3353e+00, 4.0101e+08],
#         [5.3997e-01, 4.0103e+08],
#         [1.4210e-01, 4.0103e+08],
#         [8.4443e-01, 4.0107e+08],
#         [3.5951e-01, 4.0107e+08],
#         [1.7748e+01, 4.0109e+08],
#         [4.4872e-02, 4.0111e+08],
#         [5.5495e-01, 4.0113e+08]], dtype=torch.float64)
# 61
# tensor([[5.1156e-01, 4.0113e+08],
#         [3.7025e+00, 4.0115e+08],
#         [7.9689e-01, 4.0117e+08],
#         [2.3971e+00, 4.0119e+08],
#         [1.8073e+00, 4.0119e+08],
#         [1.2945e-01, 4.0121e+08],
#         [6.9920e-02, 4.0127e+08],
#         [1.6668e+00, 4.0129e+08],
#         [4.2764e-01, 4.0131e+08],
#         [6.2672e-01, 4.0131e+08]], dtype=torch.float64)
# 62
# tensor([[4.6107e-01, 4.0135e+08],
#         [8.7745e+01, 4.0139e+08],
#         [6.1283e+00, 4.0141e+08],
#         [9.7740e+00, 4.0141e+08],
#         [2.8185e+00, 4.0143e+08],
#         [4.5185e+00, 4.0143e+08],
#         [6.1903e-02, 4.0147e+08],
#         [3.4666e-01, 4.0147e+08],
#         [4.1926e+00, 4.0149e+08],
#         [6.3330e+00, 4.0153e+08]], dtype=torch.float64)
# 63
# tensor([[1.2026e+01, 4.1001e+08],
#         [8.2432e+00, 4.1001e+08],
#         [6.6477e+00, 4.1003e+08],
#         [1.8407e+01, 4.1005e+08],
#         [3.2705e-01, 4.1007e+08],
#         [3.2349e+00, 4.1009e+08],
#         [1.0120e+00, 4.1011e+08],
#         [2.6960e+00, 4.1013e+08],
#         [7.3404e-01, 4.1015e+08],
#         [8.1774e+00, 4.1017e+08]], dtype=torch.float64)
# 64
# tensor([[3.1956e-01, 4.1019e+08],
#         [4.1643e-01, 4.1019e+08],
#         [2.8303e+00, 4.1021e+08],
#         [5.5597e-01, 4.1023e+08],
#         [1.0737e+01, 4.1025e+08],
#         [3.1209e+00, 4.1027e+08],
#         [2.4878e+00, 4.1029e+08],
#         [1.2970e+01, 4.1035e+08],
#         [5.3450e+00, 4.1039e+08],
#         [3.4166e+00, 4.1045e+08]], dtype=torch.float64)
# 65
# tensor([[5.7873e+01, 4.1047e+08],
#         [8.0821e+01, 4.1047e+08],
#         [5.3245e+01, 4.1049e+08],
#         [4.1358e+00, 4.1055e+08],
#         [4.0491e+00, 4.1055e+08],
#         [2.0757e+01, 4.1059e+08],
#         [7.2412e-01, 4.1063e+08],
#         [1.1287e+01, 4.1071e+08],
#         [1.2793e+01, 4.1071e+08],
#         [2.3813e-01, 4.6003e+08]], dtype=torch.float64)
# 66
# tensor([[1.9700e+00, 4.6005e+08],
#         [1.1514e+01, 4.6007e+08],
#         [4.0557e+00, 4.6007e+08],
#         [7.6008e+00, 4.6011e+08],
#         [1.2347e+00, 4.6013e+08],
#         [3.6764e+00, 4.6013e+08],
#         [4.8369e+00, 4.6017e+08],
#         [7.3933e-01, 4.6019e+08],
#         [3.3199e-01, 4.6019e+08],
#         [7.1401e+00, 4.6021e+08]], dtype=torch.float64)
# 67
# tensor([[2.9526e+00, 4.6021e+08],
#         [8.8058e-01, 4.6023e+08],
#         [4.0180e+00, 4.6025e+08],
#         [6.5841e+00, 4.6027e+08],
#         [1.2383e+01, 4.6027e+08],
#         [7.5896e+00, 4.6029e+08],
#         [7.0143e+00, 4.6029e+08],
#         [4.7238e-01, 4.6033e+08],
#         [7.1552e-01, 4.6035e+08],
#         [5.6293e-01, 4.6037e+08]], dtype=torch.float64)
# 68
# tensor([[2.3229e+00, 4.6043e+08],
#         [1.1492e+00, 4.6045e+08],
#         [3.0921e-01, 4.6045e+08],
#         [9.5680e+00, 4.6051e+08],
#         [4.9045e+00, 4.6057e+08],
#         [1.6589e-01, 4.6059e+08],
#         [3.6490e-01, 4.6061e+08],
#         [7.1741e-02, 4.6063e+08],
#         [1.4348e-01, 4.6063e+08],
#         [3.0479e+00, 4.6065e+08]], dtype=torch.float64)
# 69
# tensor([[6.2661e-02, 4.6071e+08],
#         [7.3701e-01, 4.6073e+08],
#         [1.0581e+00, 4.6075e+08],
#         [2.5487e+00, 4.6077e+08],
#         [5.7721e+00, 4.6079e+08],
#         [4.0296e+00, 4.6081e+08],
#         [2.8287e+00, 4.6081e+08],
#         [3.6267e+00, 4.6083e+08],
#         [3.0215e-01, 4.6085e+08],
#         [1.0271e+00, 4.6087e+08]], dtype=torch.float64)
# 70
# tensor([[8.4366e-01, 4.6087e+08],
#         [1.7526e-01, 4.6089e+08],
#         [4.5208e+00, 4.6091e+08],
#         [5.4417e-01, 4.6091e+08],
#         [2.0363e-01, 4.6097e+08],
#         [3.5172e-01, 4.6097e+08],
#         [1.8335e+01, 4.6099e+08],
#         [4.0860e+00, 4.6101e+08],
#         [5.9155e+00, 4.6103e+08],
#         [1.1258e-01, 4.6105e+08]], dtype=torch.float64)
# 71
# tensor([[1.7414e+00, 4.6109e+08],
#         [3.0648e-01, 4.6111e+08],
#         [3.0648e-01, 4.6111e+08],
#         [5.7775e+00, 4.6115e+08],
#         [1.4064e+00, 4.6119e+08],
#         [8.1504e-01, 4.6119e+08],
#         [1.7784e+00, 4.6123e+08],
#         [3.2353e+00, 4.6125e+08],
#         [7.0287e+00, 4.6127e+08],
#         [8.7124e+00, 4.6127e+08]], dtype=torch.float64)
# 72
# tensor([[7.5003e-01, 4.6129e+08],
#         [6.7269e+00, 4.6135e+08],
#         [9.5488e+00, 4.6135e+08],
#         [4.5979e-02, 4.6137e+08],
#         [6.7615e-02, 4.6137e+08],
#         [4.2651e+00, 4.8001e+08],
#         [7.2628e+00, 4.8005e+08],
#         [2.9738e-01, 4.8009e+08],
#         [2.1159e-01, 4.8009e+08],
#         [2.6279e+00, 4.8011e+08]], dtype=torch.float64)
# 73
# tensor([[1.6930e+01, 4.8013e+08],
#         [1.4213e+01, 4.8013e+08],
#         [4.5716e+00, 4.8015e+08],
#         [4.1774e+01, 4.8017e+08],
#         [2.1988e+00, 4.8019e+08],
#         [1.4059e+00, 4.8023e+08],
#         [4.5156e+00, 4.8025e+08],
#         [2.6950e+00, 4.8025e+08],
#         [1.0645e+02, 4.8029e+08],
#         [1.4149e+00, 4.8031e+08]], dtype=torch.float64)
# 74
# tensor([[2.0076e+00, 4.8031e+08],
#         [2.3048e+00, 4.8035e+08],
#         [5.0945e+00, 4.8037e+08],
#         [5.2943e+01, 4.8041e+08],
#         [4.4190e+01, 4.8041e+08],
#         [6.3652e-01, 4.8049e+08],
#         [9.2944e+00, 4.8051e+08],
#         [2.9847e+00, 4.8053e+08],
#         [2.2934e+00, 4.8055e+08],
#         [8.0833e-01, 4.8057e+08]], dtype=torch.float64)
# 75
# tensor([[7.4129e-01, 4.8059e+08],
#         [4.0006e-01, 4.8059e+08],
#         [1.6347e+00, 4.8061e+08],
#         [1.3266e+00, 4.8061e+08],
#         [4.8381e+01, 4.8065e+08],
#         [4.6657e-01, 4.8067e+08],
#         [1.9181e+02, 4.8069e+08],
#         [1.3616e+02, 4.8069e+08],
#         [2.8033e+00, 4.8071e+08],
#         [3.4736e+00, 4.8073e+08]], dtype=torch.float64)
# 76
# tensor([[7.8119e+00, 4.8075e+08],
#         [1.2076e+00, 4.8077e+08],
#         [7.6242e-01, 4.8077e+08],
#         [4.1399e+01, 4.8079e+08],
#         [4.6297e+01, 4.8079e+08],
#         [3.4374e-01, 4.8081e+08],
#         [2.8966e-02, 4.8083e+08],
#         [3.7499e+00, 4.8085e+08],
#         [2.5393e+01, 4.8087e+08],
#         [1.5272e+01, 4.8091e+08]], dtype=torch.float64)
# 77
# tensor([[3.4036e+00, 4.8095e+08],
#         [2.6626e+00, 4.8097e+08],
#         [1.1886e+00, 4.8099e+08],
#         [4.1833e+01, 4.8107e+08],
#         [2.0184e+01, 4.8107e+08],
#         [1.1650e+02, 4.8111e+08],
#         [9.4543e+01, 4.8111e+08],
#         [4.2269e+01, 4.8115e+08],
#         [6.4741e+00, 4.8121e+08],
#         [4.9579e+00, 4.8123e+08]], dtype=torch.float64)
# 78
# tensor([[4.7621e+00, 4.8125e+08],
#         [1.3678e+01, 4.8129e+08],
#         [1.0714e+00, 4.8131e+08],
#         [4.0919e+00, 4.8135e+08],
#         [1.7282e-01, 4.8137e+08],
#         [8.1285e+00, 4.8141e+08],
#         [5.1557e+00, 4.8143e+08],
#         [1.3754e+00, 4.8149e+08],
#         [2.6699e+00, 4.8151e+08],
#         [4.9826e+01, 4.8153e+08]], dtype=torch.float64)
# 79
# tensor([[4.0139e+01, 4.8153e+08],
#         [1.5899e+00, 4.8155e+08],
#         [3.5749e+01, 4.8157e+08],
#         [4.3637e+01, 4.8157e+08],
#         [1.9340e+00, 4.8159e+08],
#         [2.5931e+01, 4.8163e+08],
#         [2.6038e+01, 4.8163e+08],
#         [1.0244e+02, 4.8165e+08],
#         [4.0565e+00, 4.8169e+08],
#         [3.0571e+00, 4.8171e+08]], dtype=torch.float64)
# 80
# tensor([[1.5108e+01, 4.8173e+08],
#         [1.8145e+00, 4.8175e+08],
#         [2.4582e+00, 4.8175e+08],
#         [1.3286e+01, 4.8179e+08],
#         [1.6166e+01, 4.8179e+08],
#         [6.2982e+00, 4.8181e+08],
#         [5.9622e+00, 4.8183e+08],
#         [2.3660e+00, 4.8183e+08],
#         [2.1249e+00, 4.8185e+08],
#         [4.8664e+00, 4.8187e+08]], dtype=torch.float64)
# 81
# tensor([[3.8621e+00, 4.8187e+08],
#         [9.9652e+01, 4.8189e+08],
#         [7.8070e+01, 4.8195e+08],
#         [2.3365e+00, 4.8199e+08],
#         [6.8724e+01, 4.8201e+08],
#         [1.8316e+00, 4.8203e+08],
#         [1.0995e+02, 4.8205e+08],
#         [1.8870e+01, 4.8207e+08],
#         [6.6469e+00, 4.8209e+08],
#         [3.4650e+00, 4.8211e+08]], dtype=torch.float64)
# 82
# tensor([[3.4121e+00, 4.8215e+08],
#         [5.2826e+01, 4.8219e+08],
#         [9.6905e+00, 4.8221e+08],
#         [9.4851e+00, 4.8221e+08],
#         [4.1031e+00, 4.8223e+08],
#         [2.6231e+00, 4.8223e+08],
#         [1.6032e+00, 4.8225e+08],
#         [1.2606e+00, 4.8225e+08],
#         [6.6781e+00, 4.8229e+08],
#         [8.7846e+00, 4.8229e+08]], dtype=torch.float64)
# 83
# tensor([[9.4031e-01, 4.8231e+08],
#         [3.6431e-01, 4.8235e+08],
#         [2.4984e+01, 4.8239e+08],
#         [6.3180e-01, 4.8243e+08],
#         [4.9507e-01, 4.8243e+08],
#         [6.2845e+00, 4.8245e+08],
#         [5.2406e+00, 4.8245e+08],
#         [5.3511e-01, 4.8247e+08],
#         [2.1269e+00, 4.8249e+08],
#         [3.9760e+00, 4.8251e+08]], dtype=torch.float64)
# 84
# tensor([[1.3367e+00, 4.8253e+08],
#         [5.5082e+00, 4.8255e+08],
#         [1.7297e+00, 4.8257e+08],
#         [3.4464e-01, 4.8257e+08],
#         [3.4964e+00, 4.8259e+08],
#         [2.8335e-01, 4.8261e+08],
#         [6.8358e-01, 4.8263e+08],
#         [2.3213e+00, 4.8265e+08],
#         [1.0067e+00, 4.8269e+08],
#         [1.7457e-01, 4.8269e+08]], dtype=torch.float64)
# 85
# tensor([[8.5218e-01, 4.8271e+08],
#         [1.4903e+00, 4.8271e+08],
#         [1.6301e+01, 4.8275e+08],
#         [1.6227e+01, 4.8275e+08],
#         [2.1562e+00, 4.8283e+08],
#         [3.6528e+00, 4.8283e+08],
#         [6.0479e+00, 4.8287e+08],
#         [1.8144e+00, 4.8289e+08],
#         [4.0545e+00, 4.8291e+08],
#         [1.6848e+01, 4.8295e+08]], dtype=torch.float64)
# 86
# tensor([[1.8353e+01, 4.8295e+08],
#         [1.6000e+00, 4.8297e+08],
#         [5.6953e-01, 4.8299e+08],
#         [5.9691e-01, 4.8299e+08],
#         [1.4196e-01, 4.8301e+08],
#         [5.4494e+00, 4.8309e+08],
#         [1.9294e+00, 4.8311e+08],
#         [3.8500e+00, 4.8313e+08],
#         [4.5851e-01, 4.8315e+08],
#         [1.0282e+01, 4.8321e+08]], dtype=torch.float64)
# 87
# tensor([[1.1009e+01, 4.8325e+08],
#         [7.4712e-01, 4.8327e+08],
#         [5.1769e-01, 4.8327e+08],
#         [1.3900e+00, 4.8333e+08],
#         [7.6568e+00, 4.8335e+08],
#         [1.3783e+00, 4.8337e+08],
#         [6.7509e-01, 4.8337e+08],
#         [3.5422e+01, 4.8339e+08],
#         [3.1541e+01, 4.8339e+08],
#         [1.0086e+00, 4.8343e+08]], dtype=torch.float64)
# 88
# tensor([[3.2514e+00, 4.8345e+08],
#         [4.3961e+00, 4.8345e+08],
#         [3.3838e+00, 4.8347e+08],
#         [6.2411e-01, 4.8349e+08],
#         [2.2255e-01, 4.8349e+08],
#         [1.3199e+00, 4.8351e+08],
#         [8.9465e-01, 4.8351e+08],
#         [5.4920e+00, 4.8353e+08],
#         [6.9291e+00, 4.8353e+08],
#         [4.3516e+00, 4.8355e+08]], dtype=torch.float64)
# 89
# tensor([[3.3198e+01, 4.8357e+08],
#         [4.1415e+01, 4.8357e+08],
#         [1.4412e+01, 4.8361e+08],
#         [2.1679e+00, 4.8363e+08],
#         [3.0050e-01, 4.8363e+08],
#         [3.0739e+00, 4.8365e+08],
#         [4.0784e+00, 4.8367e+08],
#         [8.4560e+01, 4.8369e+08],
#         [1.2849e+01, 4.8371e+08],
#         [2.0573e+00, 4.8375e+08]], dtype=torch.float64)
# 90
# tensor([[6.0909e-01, 4.8377e+08],
#         [5.6707e-01, 4.8379e+08],
#         [1.5072e+01, 4.8381e+08],
#         [8.3853e+00, 4.8383e+08],
#         [1.0183e+01, 4.8383e+08],
#         [5.5324e-01, 4.8385e+08],
#         [4.0167e-01, 4.8385e+08],
#         [7.9411e+00, 4.8389e+08],
#         [1.0583e+00, 4.8391e+08],
#         [1.1873e+01, 4.8393e+08]], dtype=torch.float64)
# 91
# tensor([[3.9232e+00, 4.8393e+08],
#         [5.4975e+01, 4.8395e+08],
#         [3.0389e+01, 4.8395e+08],
#         [1.6602e+00, 4.8397e+08],
#         [1.2707e+00, 4.8399e+08],
#         [4.0475e+00, 4.8401e+08],
#         [4.5979e+00, 4.8401e+08],
#         [8.9566e-01, 4.8405e+08],
#         [6.8185e+00, 4.8409e+08],
#         [1.0880e+00, 4.8411e+08]], dtype=torch.float64)
# 92
# tensor([[2.0970e+00, 4.8411e+08],
#         [9.3309e-01, 4.8413e+08],
#         [3.6228e+00, 4.8415e+08],
#         [1.4478e-01, 4.8417e+08],
#         [8.6867e-02, 4.8417e+08],
#         [2.3991e+00, 4.8419e+08],
#         [1.3005e+02, 4.8421e+08],
#         [6.9164e+00, 4.8423e+08],
#         [1.0303e+01, 4.8423e+08],
#         [5.0873e+00, 4.8425e+08]], dtype=torch.float64)
# 93
# tensor([[9.8591e-01, 4.8427e+08],
#         [5.0372e-01, 4.8427e+08],
#         [2.9433e-01, 4.8433e+08],
#         [8.8112e-01, 4.8435e+08],
#         [6.1721e+01, 4.8437e+08],
#         [6.3733e+00, 4.8439e+08],
#         [1.2473e+00, 4.8441e+08],
#         [1.6045e-01, 4.8443e+08],
#         [7.3768e+01, 4.8445e+08],
#         [4.7775e+01, 4.8445e+08]], dtype=torch.float64)
# 94
# tensor([[3.4739e-02, 4.8447e+08],
#         [9.2064e-01, 4.8449e+08],
#         [1.3488e+01, 4.8451e+08],
#         [9.3906e+00, 4.8453e+08],
#         [6.4376e-01, 4.8455e+08],
#         [3.3139e+00, 4.8459e+08],
#         [4.1611e+00, 4.8461e+08],
#         [1.8394e+01, 4.8463e+08],
#         [2.7016e+00, 4.8467e+08],
#         [2.4394e+00, 4.8467e+08]], dtype=torch.float64)
# 95
# tensor([[3.9166e+00, 4.8471e+08],
#         [2.7416e+00, 4.8471e+08],
#         [2.4752e+01, 4.8473e+08],
#         [1.4056e+01, 4.8473e+08],
#         [5.5771e+00, 4.8479e+08],
#         [5.4145e+01, 4.8481e+08],
#         [5.1586e+01, 4.8481e+08],
#         [8.7635e+00, 4.8483e+08],
#         [1.0653e+01, 4.8487e+08],
#         [5.6582e-01, 4.8489e+08]], dtype=torch.float64)
# 96
# tensor([[2.3298e-01, 4.8489e+08],
#         [6.2939e+00, 4.8491e+08],
#         [1.2482e+01, 4.8493e+08],
#         [2.0875e+00, 4.8495e+08],
#         [1.2094e+02, 4.8501e+08],
#         [1.2232e+01, 4.9001e+08],
#         [1.3612e+01, 4.9001e+08],
#         [5.1674e+00, 4.9003e+08],
#         [4.4361e+00, 4.9003e+08],
#         [2.5410e+01, 4.9005e+08]], dtype=torch.float64)
# 97
# tensor([[1.5303e+00, 4.9007e+08],
#         [2.3687e+01, 4.9011e+08],
#         [5.3108e-01, 4.9013e+08],
#         [1.8519e-01, 4.9015e+08],
#         [4.1978e-01, 4.9017e+08],
#         [4.7338e-01, 4.9019e+08],
#         [4.3275e+00, 4.9023e+08],
#         [5.1640e-01, 4.9025e+08],
#         [4.4170e-01, 4.9025e+08],
#         [1.8304e+00, 4.9029e+08]], dtype=torch.float64)
# 98
# tensor([[1.8477e+00, 4.9029e+08],
#         [1.6566e+00, 4.9031e+08],
#         [1.3228e+00, 4.9033e+08],
#         [5.1946e+01, 4.9035e+08],
#         [5.1322e+01, 4.9035e+08],
#         [2.1305e-01, 4.9037e+08],
#         [2.3917e-01, 4.9037e+08],
#         [6.1101e+00, 4.9039e+08],
#         [7.7170e+00, 4.9041e+08],
#         [4.5568e+00, 4.9043e+08]], dtype=torch.float64)
# 99
# tensor([[2.3640e+00, 4.9045e+08],
#         [2.6341e+00, 4.9045e+08],
#         [5.3976e+00, 4.9047e+08],
#         [5.1933e+00, 4.9047e+08],
#         [3.3303e+01, 4.9049e+08],
#         [8.1207e+00, 4.9053e+08],
#         [5.3998e+00, 4.9055e+08],
#         [3.3418e+00, 4.9055e+08],
#         [2.0728e+01, 4.9057e+08],
#         [5.2027e+01, 5.3001e+08]], dtype=torch.float64)
# 100
# tensor([[2.3145e+01, 5.3001e+08],
#         [3.9148e+00, 5.3003e+08],
#         [2.6286e+01, 5.3005e+08],
#         [1.8885e+01, 5.3005e+08],
#         [4.3351e+00, 5.3009e+08],
#         [4.1212e+00, 5.3017e+08],
#         [3.1483e+00, 5.3017e+08],
#         [5.1686e-01, 5.3019e+08],
#         [4.0718e+01, 5.3021e+08],
#         [5.8882e-01, 5.3023e+08]], dtype=torch.float64)
# 101
# tensor([[1.4634e+01, 5.3029e+08],
#         [1.4779e+01, 5.3029e+08],
#         [7.8523e-01, 5.3031e+08],
#         [1.8812e+01, 5.3033e+08],
#         [2.9762e+01, 5.3035e+08],
#         [2.5805e+01, 5.3035e+08],
#         [8.2688e+00, 5.3039e+08],
#         [6.2475e+00, 5.3039e+08],
#         [3.7941e+00, 5.3041e+08],
#         [3.1309e+00, 5.3041e+08]], dtype=torch.float64)
# 102
# tensor([[5.7935e+00, 5.3043e+08],
#         [3.9730e+00, 5.3045e+08],
#         [4.5689e+00, 5.3045e+08],
#         [9.4143e-01, 5.3049e+08],
#         [2.8374e+01, 5.3053e+08],
#         [2.7040e+00, 5.3055e+08],
#         [5.4869e+00, 5.3057e+08],
#         [3.5222e-01, 5.3059e+08],
#         [5.3616e+00, 5.3061e+08],
#         [2.7503e+00, 5.3065e+08]], dtype=torch.float64)
# 103
# tensor([[2.5529e+00, 5.3065e+08],
#         [4.0450e-01, 5.3069e+08],
#         [3.8611e-01, 5.3069e+08],
#         [2.1489e+01, 5.3071e+08],
#         [9.4931e+00, 5.3073e+08],
#         [1.6072e+01, 5.3077e+08],
#         [5.4029e-01, 5.6001e+08],
#         [8.9842e-01, 5.6001e+08],
#         [6.9043e-01, 5.6003e+08],
#         [9.7065e-01, 5.6003e+08]], dtype=torch.float64)
# 104
# tensor([[3.0748e-01, 5.6007e+08],
#         [4.2136e-01, 5.6007e+08],
#         [1.1506e+00, 5.6009e+08],
#         [1.6451e+00, 5.6011e+08],
#         [2.3283e+01, 5.6015e+08],
#         [3.9093e+01, 5.6015e+08],
#         [7.8654e-01, 5.6017e+08],
#         [6.2976e-01, 5.6017e+08],
#         [2.5714e+01, 5.6021e+08],
#         [9.4832e-01, 5.6023e+08]], dtype=torch.float64)
# 105
# tensor([[1.7345e+00, 5.6023e+08],
#         [1.1536e-01, 5.6029e+08],
#         [4.4311e-02, 5.6029e+08],
#         [1.5057e+01, 5.6031e+08],
#         [2.0603e+00, 5.6035e+08],
#         [7.2631e-01, 5.6037e+08],
#         [6.8521e-01, 5.6039e+08],
#         [1.9498e+00, 5.6043e+08],
#         [4.1617e-01, 5.6045e+08]], dtype=torch.float64)

# %%
sample_torch = torch.from_numpy(sample_arr)

sampler = DistributedSampler(sample_torch, num_replicas=3, rank=0, shuffle=False, drop_last=False)
dataloader = DataLoader(sample_torch, batch_size=10, pin_memory=False, num_workers=1, drop_last=False, shuffle=False, 
                        sampler=sampler)
i = 0    
for item in dataloader:
    i+=1
    print(i)
    print(item.cpu().detach().numpy())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [54], line 1
# ----> 1 sample_torch = torch.from_numpy(sample_arr)
#       3 sampler = DistributedSampler(sample_torch, num_replicas=3, rank=0, shuffle=False, drop_last=False)
#       4 dataloader = DataLoader(sample_torch, batch_size=10, pin_memory=False, num_workers=1, drop_last=False, shuffle=False,
#       5                         sampler=sampler)
#
# TypeError: expected np.ndarray (got Tensor)

# %%
# Trial model run

train_arr, n_inputs = create_model_input(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_data.csv',
                                     observed_csv=None,
                                     predictor_drop_columns=['fips', 'Year'], use_for_testing=False)

# Experiment on training data with small sample size
train_arr = train_arr[0:200000, :]
unq = list(np.unique(train_arr[:, -1]))
obsv_csv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv.csv'

obsv_df = pd.read_csv(obsv_csv)
obsv_df = obsv_df[obsv_df['fips_years'].isin(unq)]
obsv_df.to_csv(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv2.csv')
obsv_csv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\train_obsv2.csv'
# Out:
# Using predictors: ['GPM_PRECIP', 'MODIS_Day_LST', 'MODIS_NDWI', 'PRISM_PRECIP', 'SSEBOP_ET', 'USDA_cropland', 'USDA_developed']

# %%
start_time = time.time()

us_wateruse_nn = nn.NeuralNetwork(n_inputs, [100, 50, 10], n_outputs=1, activation_func='tanh', device='cuda')
us_wateruse_nn.train_with_distributed_T(train_arr, obsv_csv, n_epochs=3000, method='adam', learning_rate=0.01)

end_time = time.time()
time_taken = end_time - start_time

print('Time Taken', round((time_taken)/60, 2), 'mins')
# Out:
# Model running on cuda....
# adam: Epoch=100 RMSE=0.99954
# adam: Epoch=200 RMSE=1.00292
# adam: Epoch=300 RMSE=0.90146
# adam: Epoch=400 RMSE=0.91892
# adam: Epoch=500 RMSE=0.86943
# adam: Epoch=600 RMSE=1.01173
# adam: Epoch=700 RMSE=0.98796
# adam: Epoch=800 RMSE=1.02408
# adam: Epoch=900 RMSE=0.88672
# adam: Epoch=1000 RMSE=0.84509
# adam: Epoch=1100 RMSE=0.98877
# adam: Epoch=1200 RMSE=0.99801
# adam: Epoch=1300 RMSE=0.76417
# adam: Epoch=1400 RMSE=0.85347
# adam: Epoch=1500 RMSE=0.99820
# adam: Epoch=1600 RMSE=1.07412
# adam: Epoch=1700 RMSE=0.98068
# adam: Epoch=1800 RMSE=0.90709
# adam: Epoch=1900 RMSE=0.84803
# adam: Epoch=2000 RMSE=0.81228
# adam: Epoch=2100 RMSE=0.79255
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 4
#       1 start_time = time.time()
#       3 us_wateruse_nn = nn.NeuralNetwork(n_inputs, [100, 50, 10], n_outputs=1, activation_func='tanh', device='cuda')
# ----> 4 us_wateruse_nn.train_with_distributed_T(train_arr, obsv_csv, n_epochs=3000, method='adam', learning_rate=0.01)
#       6 end_time = time.time()
#       7 time_taken = end_time - start_time
#
# File H:\WestUS_wateruse\python_scripts\NeuralNetwork_model.py:295, in NeuralNetwork.train_with_distributed_T(self, X, T_csv, n_epochs, method, learning_rate, verbose, fips_years_col, epochs_to_print)
#     292 Ys = self._forward(Xs)
#     294 # grouping Ys by fips_years codes
# --> 295 Ys_stack = np.hstack((Ys.cpu().detach(), self.fips_years))  # is a numpy arrary
#     297 # T (unstandardized, numpy array) is countywise observed gw pumping data distributed among each pixel.
#     298 # This distribution will be performed in each epoch, based on prediction share of Ys in Ys_sum.
#     299 T = self.distribute_T_for_backprop(Ys_stack, T_csv)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

errors_train = us_wateruse_nn.get_performance_trace()

plt.subplots(figsize=(12, 8))
plt.plot(errors_train, '--o', color='lightblue')
plt.xlabel('Epoch')
plt.ylabel('Standardized Error')
# Out:
# Text(0, 0.5, 'Standardized Error')

# %%
val_arr, n_inputs = create_model_input(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\validation_data.csv',
                                     observed_csv=None,
                                     predictor_drop_columns=['fips', 'Year'], use_for_testing=False)
val_csv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\validation_obsv.csv'

wateruse_nn_val = nn.NeuralNetwork(n_inputs, [200, 200, 100, 30, 10], n_outputs=1, activation_func='tanh', device='cuda')
wateruse_nn_val.train_with_distributed_T(val_arr, val_csv, n_epochs=3000, method='adam', learning_rate=0.01)


test_arr, n_inputs = create_model_input(r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\test_data.csv',
                                     observed_csv=None,
                                     predictor_drop_columns=['fips', 'Year'], use_for_testing=False)
test_csv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\test_obsv.csv'

wateruse_nn_test = nn.NeuralNetwork(n_inputs, [200, 200, 100, 30, 10], n_outputs=1, activation_func='tanh', device='cuda')
wateruse_nn_test.train_with_distributed_T(test_arr, test_csv, n_epochs=3000, method='adam', learning_rate=0.01)
# Out:
# Using predictors: ['GPM_PRECIP', 'MODIS_Day_LST', 'MODIS_NDWI', 'PRISM_PRECIP', 'SSEBOP_ET', 'USDA_cropland', 'USDA_developed']
# Model running on cuda....
# adam: Epoch=100 RMSE=0.98365
# adam: Epoch=200 RMSE=1.11645
# adam: Epoch=300 RMSE=0.96066
# adam: Epoch=400 RMSE=0.93669
# adam: Epoch=500 RMSE=0.86708
# adam: Epoch=600 RMSE=1.03253
# adam: Epoch=700 RMSE=0.96487
# adam: Epoch=800 RMSE=0.88907
# adam: Epoch=900 RMSE=1.01939
# adam: Epoch=1000 RMSE=1.01288
# adam: Epoch=1100 RMSE=0.99423
# adam: Epoch=1200 RMSE=0.98003
# adam: Epoch=1300 RMSE=0.96117
# adam: Epoch=1400 RMSE=0.88495
# adam: Epoch=1500 RMSE=0.77860
# adam: Epoch=1600 RMSE=0.69332
# adam: Epoch=1700 RMSE=0.42475
# adam: Epoch=1800 RMSE=0.30201
# adam: Epoch=1900 RMSE=1.39440
# adam: Epoch=2000 RMSE=0.42992
# adam: Epoch=2100 RMSE=0.51495
# adam: Epoch=2200 RMSE=0.40542
# adam: Epoch=2300 RMSE=0.69142
# adam: Epoch=2400 RMSE=0.99187
# adam: Epoch=2500 RMSE=0.68461
# adam: Epoch=2600 RMSE=0.24710
# adam: Epoch=2700 RMSE=0.26812
# adam: Epoch=2800 RMSE=0.44758
# adam: Epoch=2900 RMSE=0.78138
# adam: Epoch=3000 RMSE=0.61194
# Using predictors: ['GPM_PRECIP', 'MODIS_Day_LST', 'MODIS_NDWI', 'PRISM_PRECIP', 'SSEBOP_ET', 'USDA_cropland', 'USDA_developed']
# Model running on cuda....
# adam: Epoch=100 RMSE=0.92580
# adam: Epoch=200 RMSE=0.56781
# adam: Epoch=300 RMSE=0.40190
# adam: Epoch=400 RMSE=0.46793
# adam: Epoch=500 RMSE=0.34216
# adam: Epoch=600 RMSE=0.90701
# adam: Epoch=700 RMSE=0.82400
# adam: Epoch=800 RMSE=0.84523
# adam: Epoch=900 RMSE=0.36720
# adam: Epoch=1000 RMSE=0.85217
# adam: Epoch=1100 RMSE=1.01273
# adam: Epoch=1200 RMSE=0.99612
# adam: Epoch=1300 RMSE=0.86367
# adam: Epoch=1400 RMSE=0.59613
# adam: Epoch=1500 RMSE=0.40136
# adam: Epoch=1600 RMSE=0.90284
# adam: Epoch=1700 RMSE=0.63537
# adam: Epoch=1800 RMSE=0.99985
# adam: Epoch=1900 RMSE=0.42156
# adam: Epoch=2000 RMSE=0.53950
# adam: Epoch=2100 RMSE=0.42350
# adam: Epoch=2200 RMSE=0.29489
# adam: Epoch=2300 RMSE=0.26511
# adam: Epoch=2400 RMSE=0.24803
# adam: Epoch=2500 RMSE=0.32274
# adam: Epoch=2600 RMSE=0.23166
# adam: Epoch=2700 RMSE=0.21142
# adam: Epoch=2800 RMSE=0.25079
# adam: Epoch=2900 RMSE=0.59760
# adam: Epoch=3000 RMSE=0.57958
# NeuralNetwork(7, [200, 200, 100, 30, 10], 1, activation func=Tanh())

# %%
print(f'train_arr={train_arr.shape}, val_arr={val_arr.shape}, test_arr={test_arr.shape}')
# Out:
# train_arr=(200000, 8), val_arr=(146634, 8), test_arr=(125602, 8)

# %%
import matplotlib.pyplot as plt

errors_train = us_wateruse_nn.get_performance_trace()
errors_val = wateruse_nn_val.get_performance_trace()
error_test = wateruse_nn_test.get_performance_trace()

errors = [errors_train, errors_val, error_test]
label = ['train', 'validation', 'test']

plt.subplots(figsize=(12, 8))
for i in range(1, 4):
    plt.subplot(1, 3, i)
    plt.plot(errors[i-1], '--o', color='lightblue')
    plt.xlabel('Epoch')
    plt.ylabel('Standardized Error')
    plt.title(f'{label[i-1]}')
plt.tight_layout()

# %%
# Testing
# train_data = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\validation_data.csv'
# train_obsv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\validation_obsv.csv'
# train_arr, n_inputs, train_obsv_arr, fips_years_train = create_model_input(train_data, train_obsv, predictor_drop_columns=['fips', 'Year'], 
#                                                          use_for_testing=True)

# Y_train = us_wateruse_nn.predict(train_arr, fips_years_train)
# rmse_train = rmse(Y_train, train_obsv_arr)

test_data = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\test_data.csv'
test_obsv = r'H:\WestUS_wateruse\Data\Compiled_data\predictor_csv\test_obsv.csv'

test_arr,  n_inputs, test_obsv_arr, fips_years_test = create_model_input(test_data, test_obsv, predictor_drop_columns=['fips', 'Year'], 
                                                        use_for_testing=True)

Y_test = us_wateruse_nn.predict(test_arr, fips_years_test)
rmse_test = rmse(Y_test, test_obsv_arr)

print(f'{rmse_test=}')
# Out:
# Using predictors: ['GPM_PRECIP', 'MODIS_Day_LST', 'MODIS_NDWI', 'PRISM_PRECIP', 'SSEBOP_ET', 'USDA_cropland']
# rmse_test=337.5584628883035

# %% [markdown]
# #############################################

# %%
import time
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nn_regression as nn  # Your file produced from the above code cell.

# %% [markdown]
# # Test 1

# %%
X = np.arange(0, 2, 0.5).reshape(-1, 1)
X.shape[1]
# Out:
# 1

# %%
X = np.arange(0, 2, 0.5).reshape(-1, 1)
T = np.sin(X) * np.sin(X * 10)

nnet = nn.NeuralNetwork(X.shape[1], [2, 2], 1, activation_func='tanh')
    
# Set all weights here to allow comparison of your calculations
# Must use [:] to overwrite values in all_weights.
# Without [:], new array is assigned to self.all_weights, so self.Ws no longer refer to same memory

nnet.train(X, T, n_epochs=100, method='sgd', learning_rate=0.1)
print(nnet)
# Out:
# Model running on cpu....
# tensor(0.9125, grad_fn=<SqrtBackward0>)
# tensor(0.8883, grad_fn=<SqrtBackward0>)
# tensor(0.8570, grad_fn=<SqrtBackward0>)
# tensor(0.8373, grad_fn=<SqrtBackward0>)
# tensor(0.8370, grad_fn=<SqrtBackward0>)
# tensor(0.8488, grad_fn=<SqrtBackward0>)
# tensor(0.8592, grad_fn=<SqrtBackward0>)
# tensor(0.8588, grad_fn=<SqrtBackward0>)
# tensor(0.8461, grad_fn=<SqrtBackward0>)
# tensor(0.8266, grad_fn=<SqrtBackward0>)
# tensor(0.8091, grad_fn=<SqrtBackward0>)
# tensor(0.7998, grad_fn=<SqrtBackward0>)
# tensor(0.7973, grad_fn=<SqrtBackward0>)
# tensor(0.7939, grad_fn=<SqrtBackward0>)
# tensor(0.7822, grad_fn=<SqrtBackward0>)
# tensor(0.7606, grad_fn=<SqrtBackward0>)
# tensor(0.7348, grad_fn=<SqrtBackward0>)
# tensor(0.7128, grad_fn=<SqrtBackward0>)
# tensor(0.6960, grad_fn=<SqrtBackward0>)
# tensor(0.6756, grad_fn=<SqrtBackward0>)
# tensor(0.6423, grad_fn=<SqrtBackward0>)
# tensor(0.5982, grad_fn=<SqrtBackward0>)
# tensor(0.5557, grad_fn=<SqrtBackward0>)
# tensor(0.5217, grad_fn=<SqrtBackward0>)
# tensor(0.4891, grad_fn=<SqrtBackward0>)
# tensor(0.4522, grad_fn=<SqrtBackward0>)
# tensor(0.4182, grad_fn=<SqrtBackward0>)
# tensor(0.3974, grad_fn=<SqrtBackward0>)
# tensor(0.3866, grad_fn=<SqrtBackward0>)
# tensor(0.3749, grad_fn=<SqrtBackward0>)
# tensor(0.3661, grad_fn=<SqrtBackward0>)
# tensor(0.3622, grad_fn=<SqrtBackward0>)
# tensor(0.3559, grad_fn=<SqrtBackward0>)
# tensor(0.3547, grad_fn=<SqrtBackward0>)
# tensor(0.3494, grad_fn=<SqrtBackward0>)
# tensor(0.3443, grad_fn=<SqrtBackward0>)
# tensor(0.3397, grad_fn=<SqrtBackward0>)
# tensor(0.3349, grad_fn=<SqrtBackward0>)
# tensor(0.3286, grad_fn=<SqrtBackward0>)
# tensor(0.3222, grad_fn=<SqrtBackward0>)
# tensor(0.3129, grad_fn=<SqrtBackward0>)
# tensor(0.3076, grad_fn=<SqrtBackward0>)
# tensor(0.2964, grad_fn=<SqrtBackward0>)
# tensor(0.2875, grad_fn=<SqrtBackward0>)
# tensor(0.2803, grad_fn=<SqrtBackward0>)
# tensor(0.2735, grad_fn=<SqrtBackward0>)
# tensor(0.2714, grad_fn=<SqrtBackward0>)
# tensor(0.2708, grad_fn=<SqrtBackward0>)
# tensor(0.2731, grad_fn=<SqrtBackward0>)
# tensor(0.2730, grad_fn=<SqrtBackward0>)
# tensor(0.2697, grad_fn=<SqrtBackward0>)
# tensor(0.2623, grad_fn=<SqrtBackward0>)
# tensor(0.2494, grad_fn=<SqrtBackward0>)
# tensor(0.2341, grad_fn=<SqrtBackward0>)
# tensor(0.2178, grad_fn=<SqrtBackward0>)
# tensor(0.2035, grad_fn=<SqrtBackward0>)
# tensor(0.1921, grad_fn=<SqrtBackward0>)
# tensor(0.1823, grad_fn=<SqrtBackward0>)
# tensor(0.1725, grad_fn=<SqrtBackward0>)
# tensor(0.1580, grad_fn=<SqrtBackward0>)
# tensor(0.1349, grad_fn=<SqrtBackward0>)
# tensor(0.1011, grad_fn=<SqrtBackward0>)
# tensor(0.0651, grad_fn=<SqrtBackward0>)
# tensor(0.0703, grad_fn=<SqrtBackward0>)
# tensor(0.1102, grad_fn=<SqrtBackward0>)
# tensor(0.0780, grad_fn=<SqrtBackward0>)
# tensor(0.0878, grad_fn=<SqrtBackward0>)
# tensor(0.1193, grad_fn=<SqrtBackward0>)
# tensor(0.0948, grad_fn=<SqrtBackward0>)
# tensor(0.0559, grad_fn=<SqrtBackward0>)
# tensor(0.1621, grad_fn=<SqrtBackward0>)
# tensor(0.1230, grad_fn=<SqrtBackward0>)
# tensor(0.0745, grad_fn=<SqrtBackward0>)
# tensor(0.0967, grad_fn=<SqrtBackward0>)
# tensor(0.1774, grad_fn=<SqrtBackward0>)
# tensor(0.0948, grad_fn=<SqrtBackward0>)
# tensor(0.1082, grad_fn=<SqrtBackward0>)
# tensor(0.1894, grad_fn=<SqrtBackward0>)
# tensor(0.0697, grad_fn=<SqrtBackward0>)
# tensor(0.2444, grad_fn=<SqrtBackward0>)
# tensor(0.1140, grad_fn=<SqrtBackward0>)
# tensor(0.3617, grad_fn=<SqrtBackward0>)
# tensor(0.3538, grad_fn=<SqrtBackward0>)
# tensor(0.0869, grad_fn=<SqrtBackward0>)
# tensor(0.2537, grad_fn=<SqrtBackward0>)
# tensor(0.1605, grad_fn=<SqrtBackward0>)
# tensor(0.2617, grad_fn=<SqrtBackward0>)
# tensor(0.2877, grad_fn=<SqrtBackward0>)
# tensor(0.0183, grad_fn=<SqrtBackward0>)
# tensor(0.2997, grad_fn=<SqrtBackward0>)
# tensor(0.3012, grad_fn=<SqrtBackward0>)
# tensor(0.2018, grad_fn=<SqrtBackward0>)
# tensor(0.2563, grad_fn=<SqrtBackward0>)
# tensor(0.2323, grad_fn=<SqrtBackward0>)
# tensor(0.0891, grad_fn=<SqrtBackward0>)
# tensor(0.2026, grad_fn=<SqrtBackward0>)
# tensor(0.1581, grad_fn=<SqrtBackward0>)
# tensor(0.1318, grad_fn=<SqrtBackward0>)
# tensor(0.1720, grad_fn=<SqrtBackward0>)
# tensor(0.1145, grad_fn=<SqrtBackward0>)
# NeuralNetwork(1, [2, 2], 1, activation func=Tanh())
#  Trained for 100 epochs.
#  Final standardized training error 0.1145.

# %%
# nnet.Zs

# %%
# nnet.Grads

# %%
Y = nnet.predict(X)
Y
# Out:
# tensor([[-0.0300],
#         [-0.4876],
#         [-0.4874],
#         [ 0.6201]])

# %%
nnet.get_performance_trace()[-1]
# Out:
# 0.09221838414669037

# %%
X = np.arange(0, 2, 0.05).reshape(-1, 1)
T = np.sin(X) * np.sin(X * 10)

n_epochs = 10000
method_rhos = [('sgd', 0.05),
               ('adam', 0.05)]
errors = []
for method, rho in method_rhos:
    
    print('\n=========================================')
    print(f'method is {method} and rho is {rho}')
    print('=========================================\n')
    
    start_time = time.time()
    
    nnet = nn.NeuralNetwork(X.shape[1], [20, 20], 1, activation_func='tanh', device='cpu')
    nnet.train(X, T, n_epochs, method=method, learning_rate=rho)
    Y = nnet.predict(X)
    errors.append(nnet.get_performance_trace())
    
    time_elapsed = time.time() - start_time
    print('Time elapsed {:.2f} sec'.format(time_elapsed))  
    
    plt.plot(X, Y, 'o-', label='Model ' + method)

plt.plot(X, T, 'o', label='Train')
plt.xlabel('X')
plt.ylabel('T or Y')
plt.legend();
# Out:
# =========================================
# method is sgd and rho is 0.05
# =========================================
#
# Model running on cpu....
# sgd: Epoch=1000 RMSE=0.08425
# sgd: Epoch=2000 RMSE=0.08154
# sgd: Epoch=3000 RMSE=0.08008
# sgd: Epoch=4000 RMSE=0.07814
# sgd: Epoch=5000 RMSE=0.07783
# sgd: Epoch=6000 RMSE=0.07662
# sgd: Epoch=7000 RMSE=0.07569
# sgd: Epoch=8000 RMSE=0.07476
# sgd: Epoch=9000 RMSE=0.07443
# sgd: Epoch=10000 RMSE=0.07323
# Time elapsed 11.09 sec
#
# =========================================
# method is adam and rho is 0.05
# =========================================
#
# Model running on cpu....
# adam: Epoch=1000 RMSE=0.03616
# adam: Epoch=2000 RMSE=0.03225
# adam: Epoch=3000 RMSE=0.02996
# adam: Epoch=4000 RMSE=0.03238
# adam: Epoch=5000 RMSE=0.02891
# adam: Epoch=6000 RMSE=0.04946
# adam: Epoch=7000 RMSE=0.06376
# adam: Epoch=8000 RMSE=0.06119
# adam: Epoch=9000 RMSE=0.04756
# adam: Epoch=10000 RMSE=0.03924
# Time elapsed 16.70 sec

# %%
for error_trace in errors:
    plt.plot(error_trace)
plt.xlabel('Epoch')
plt.ylabel('Standardized error')
plt.legend([mr[0] for mr in method_rhos]);

# %% [markdown]
# # Test 2

# %%
n_samples = 10000
X = np.linspace(0, 10, n_samples).reshape((-1, 1))
T = X ** 2
n_samples, n_inputs = X.shape 
n_outputs = T.shape[1]

nn_model = nn.NeuralNetwork(X.shape[1], [50, 50], 1, activation_func='tanh')
nn_model.train(X, T, n_epochs=10000, method='adam', learning_rate=0.1)
Y = nn_model.predict(X)
# Out:
# Model running on cpu....
# adam: Epoch=1000 RMSE=1.52083
# adam: Epoch=2000 RMSE=1.35498
# adam: Epoch=3000 RMSE=1.27533
# adam: Epoch=4000 RMSE=1.31682
# adam: Epoch=5000 RMSE=1.25491
# adam: Epoch=6000 RMSE=0.67601
# adam: Epoch=7000 RMSE=0.68667
# adam: Epoch=8000 RMSE=0.69719
# adam: Epoch=9000 RMSE=0.66027
# adam: Epoch=10000 RMSE=0.63705

# %%
plt.plot(X, T, 'o-', label='T')
plt.plot(X, Y, 'o-', label='Y')
plt.legend();

# %% [markdown]
# ## Application to Seoul Bike Sharing Demand Data

# %% [markdown]
# Download data from [bike-sharing.csv](https://www.cs.colostate.edu/~anderson/cs545/notebooks/bike-sharing.csv).  This is data modified very slightly from [UC Irvine ML Repo](https://archive-beta.ics.uci.edu/ml/datasets/seoul+bike+sharing+demand#Abstract). Read it into python using the `pandas.read_csv` function.  Assign `X` and `T` as shown.

# %%
import pandas as pd

data = pd.read_csv('SeoulBikeData.csv')
T = data['Rented Bike Count'].to_numpy().reshape(-1, 1)
X = data[['Hour', 'Temperature(C)', 'Humidity(%)',
          'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(C)',
          'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)']].to_numpy()
X.shape, T.shape
# Out:
# ((8760, 9), (8760, 1))

# %%
import itertools

def partition(X, T, train_fraction):
    """
    Creates train and test datasets.
    
    :param X: 2D numpy array.
              The input variables of the model.
    :param T: 2D numpy array
              The output variable of the model.
    :param X: float
              fraction of data in training set.
              The input variables of the model.
    
    return: Xtrain, Ttrain, Xtest, Ttest
    
    """
    n_samples = X.shape[0]
    rows = np.arange(n_samples)
    np.random.shuffle(rows)

    n_train = round(n_samples * train_fraction)
    Xtrain = X[rows[:n_train], :]
    Ttrain = T[rows[:n_train], :]
    Xtest = X[rows[n_train:], :]
    Ttest = T[rows[n_train:], :]

    return Xtrain, Ttrain, Xtest, Ttest

def rmse(T, Y):
    if isinstance(T, torch.Tensor):
        T = T.numpy()
    return np.sqrt(np.mean((T - Y)**2))

def make_param_grid(structure, rho, epoch):
    """
    Makes a gridspace with all possible combinations of input parameters.
    
    :param structure: list of int
                      Number of units in each hidden layers. Each element of the list represents one hidden layer.
    :param rho: float
                Learning rate of the model.
    :param epoch: int
                  Number of epoch to run the model.
                  
    :return: A list of all parameter combinations.
    """
    param_combs = list(itertools.product(*[structure, rho, epoch]))
    return param_combs


def configure_nnet_model(X, T, structures, rhos, epochs, method, train_test_ratio):
    """
    Runs the model for number of times of parameter combinations and saves model layout, train rmse, and test rmse. 
    
    :param X: 2D numpy array.
              The input variables of the model.
    :param T: 2D numpy array
              The output variable of the model.
    :param structures: A nested list of int, such as [[50, 20], [30, 10]]
                       Number of units in each hidden layers. Each element of the list represents one hidden layer.
    :param rhos: list of float
                 Learning rate of the model.
    :param epochs: list of int
                   Number of epoch to run the model.
    :param method : str
                    Optimization method. Accepted str from - 'sgd', 'adam', or 'scg'.
    :param train_test_ratio: float
                             ratio of dataset in training.
    
    :return: A dataframe with model layouts and respective train test rmse.
    """
    import nn_regression as nn
    
    parameter_combinations = make_param_grid(structures, rhos, epochs)

    Xtrain, Ttrain, Xtest, Ttest = partition(X, T, train_test_ratio)

    n_inputs, n_outputs = Xtrain.shape[1], Ttrain.shape[1]

    result_dict = {'Method': [], 'Structure': [], 'Epochs': [], 'Learning Rate': [], 'Train RMSE': [], 
                   'Test RMSE': []}

    for params in parameter_combinations:
        hidden_layers, rho, epoch = params
        nn_model = nn.NeuralNetwork(n_inputs, hidden_layers, n_outputs, activation_func='tanh', device='cpu')
        nn_model.train(Xtrain, Ttrain, n_epochs=epoch, method=method, learning_rate=rho, verbose=False)
        
        # RMSE (No standardization is required)
        Ttrain_predicted = nn_model.predict(Xtrain)
        rmse_train = rmse(Ttrain_predicted, Ttrain)
        
        Ttest_predicted = nn_model.predict(Xtest)
        rmse_test = rmse(Ttest_predicted, Ttest)
        
        print(f'Training for {method=}, {hidden_layers=}, {rho=}, {epoch=}, train rmse={rmse_train:.2f}, test rmse={rmse_test:.2f}')
        
        # appending results to the result dictionary
        result_dict['Method'].append(method)
        result_dict['Structure'].append(hidden_layers)
        result_dict['Epochs'].append(epoch)
        result_dict['Learning Rate'].append(rho)
        result_dict['Train RMSE'].append(rmse_train)
        result_dict['Test RMSE'].append(rmse_test)

    result_df = pd.DataFrame(result_dict)
    result_df.sort_values(by=['Test RMSE'], axis=0, ascending=True, inplace=True)

    return result_df

# %%
# Assuming you have assigned `X` and `T` correctly.

Xtrain, Ttrain, Xtest, Ttest = partition(X, T, 0.8)

Xtrain.shape, Ttrain.shape, Xtest.shape, Ttest.shape
# Out:
# ((7008, 9), (7008, 1), (1752, 9), (1752, 1))

# %%
# Searching for best model layout for Seoul Bike data
nnet_structure = [[10, 10, 10, 10], [30, 10]]
nnet_rho = [0.5, 0.01]
nnet_epoch = [5000, 10000]

# %% [markdown]
# # SGD

# %%
sgd_results = configure_nnet_model(X, T, nnet_structure, nnet_rho, nnet_epoch, method='sgd', train_test_ratio=0.8)
sgd_results
# Out:
# Model running on cpu....
# Training for method='sgd', hidden_layers=[10, 10, 10, 10], rho=0.5, epoch=5000, train rmse=301.00, test rmse=381.69
# Model running on cpu....
# Training for method='sgd', hidden_layers=[10, 10, 10, 10], rho=0.5, epoch=10000, train rmse=283.92, test rmse=377.65
# Model running on cpu....
# Training for method='sgd', hidden_layers=[10, 10, 10, 10], rho=0.01, epoch=5000, train rmse=320.48, test rmse=329.98
# Model running on cpu....
# Training for method='sgd', hidden_layers=[10, 10, 10, 10], rho=0.01, epoch=10000, train rmse=303.84, test rmse=313.23
# Model running on cpu....
# Training for method='sgd', hidden_layers=[30, 10], rho=0.5, epoch=5000, train rmse=296.32, test rmse=371.75
# Model running on cpu....
# Training for method='sgd', hidden_layers=[30, 10], rho=0.5, epoch=10000, train rmse=249.93, test rmse=355.07
# Model running on cpu....
# Training for method='sgd', hidden_layers=[30, 10], rho=0.01, epoch=5000, train rmse=319.23, test rmse=330.31
# Model running on cpu....
# Training for method='sgd', hidden_layers=[30, 10], rho=0.01, epoch=10000, train rmse=299.89, test rmse=323.39
#   Method         Structure  Epochs  Learning Rate  Train RMSE   Test RMSE
# 3    sgd  [10, 10, 10, 10]   10000           0.01  303.836855  313.234396
# 7    sgd          [30, 10]   10000           0.01  299.888241  323.388866
# 2    sgd  [10, 10, 10, 10]    5000           0.01  320.482692  329.977685
# 6    sgd          [30, 10]    5000           0.01  319.229750  330.310785
# 5    sgd          [30, 10]   10000           0.50  249.930452  355.067812
# 4    sgd          [30, 10]    5000           0.50  296.316112  371.748819
# 1    sgd  [10, 10, 10, 10]   10000           0.50  283.919857  377.652470
# 0    sgd  [10, 10, 10, 10]    5000           0.50  301.004543  381.692954

# %% [markdown]
# # Adam

# %%
adam_results = configure_nnet_model(X, T, nnet_structure, nnet_rho, nnet_epoch, method='adam', train_test_ratio=0.8)
adam_results
# Out:
# Model running on cpu....
# Training for method='adam', hidden_layers=[10, 10, 10, 10], rho=0.5, epoch=5000, train rmse=562.64, test rmse=566.38
# Model running on cpu....
# Training for method='adam', hidden_layers=[10, 10, 10, 10], rho=0.5, epoch=10000, train rmse=480.31, test rmse=482.16
# Model running on cpu....
# Training for method='adam', hidden_layers=[10, 10, 10, 10], rho=0.01, epoch=5000, train rmse=267.91, test rmse=320.51
# Model running on cpu....
# Training for method='adam', hidden_layers=[10, 10, 10, 10], rho=0.01, epoch=10000, train rmse=267.54, test rmse=319.39
# Model running on cpu....
# Training for method='adam', hidden_layers=[30, 10], rho=0.5, epoch=5000, train rmse=347.52, test rmse=383.58
# Model running on cpu....
# Training for method='adam', hidden_layers=[30, 10], rho=0.5, epoch=10000, train rmse=367.63, test rmse=417.39
# Model running on cpu....
# Training for method='adam', hidden_layers=[30, 10], rho=0.01, epoch=5000, train rmse=257.83, test rmse=334.24
# Model running on cpu....
# Training for method='adam', hidden_layers=[30, 10], rho=0.01, epoch=10000, train rmse=252.82, test rmse=334.72
#   Method         Structure  Epochs  Learning Rate  Train RMSE   Test RMSE
# 3   adam  [10, 10, 10, 10]   10000           0.01  267.544094  319.390781
# 2   adam  [10, 10, 10, 10]    5000           0.01  267.912231  320.509991
# 6   adam          [30, 10]    5000           0.01  257.830726  334.243872
# 7   adam          [30, 10]   10000           0.01  252.823423  334.715162
# 4   adam          [30, 10]    5000           0.50  347.515717  383.575113
# 5   adam          [30, 10]   10000           0.50  367.630170  417.386529
# 1   adam  [10, 10, 10, 10]   10000           0.50  480.314211  482.158306
# 0   adam  [10, 10, 10, 10]    5000           0.50  562.635930  566.378480

# %% [markdown]
# # Extra Credit
#
# Using a network that gives you pretty good test RMSE results, try to figure out which input features are most significant in predicting the bike-share count.  Remember, that our neural networks is trained with standardized inputs, so you can compare the magnitudes of weights in the first layer to help you determine which inputs are most significant.
#
# To visualize the weights, try displaying the weights in the first layer as an image, with `plt.imshow` with `plt.colorbar()`. Discuss which weights have the largest magnitudes and discuss any patterns in see in the weights in each hidden unit of the first layer.

# %% [markdown]
#  <h2> Finding Out the Most Significant Predictor </h2>
#
#  We will perform this analysis with the best model from previous experiment which is trained with <b> Adam </b> optimizer, <b> [10, 10, 5, 5] </b> structure, <b> 5000 </b> epoch, and <b> 0.001 </b> learning rate.

# %%
import pandas as pd

data = pd.read_csv('SeoulBikeData.csv')
T = data['Rented Bike Count'].to_numpy().reshape(-1, 1)
X = data[['Hour', 'Temperature(C)', 'Humidity(%)',
          'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(C)',
          'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)']].to_numpy()


Xtrain, Ttrain, Xtest, Ttest = partition(X, T, 0.8)
n_inputs, n_outputs = Xtrain.shape[1], Ttrain.shape[1] 

best_model = nn.NeuralNetwork(n_inputs, [10, 10, 10, 10], n_outputs)
best_model.train(Xtrain, Ttrain, n_epochs=10000, method='adam', learning_rate=0.01, verbose=True)
# Out:
# Model running on cpu....
# adam: Epoch=1000 RMSE=0.47442
# adam: Epoch=2000 RMSE=0.45591
# adam: Epoch=3000 RMSE=0.44532
# adam: Epoch=4000 RMSE=0.43788
# adam: Epoch=5000 RMSE=0.42783
# adam: Epoch=6000 RMSE=0.42343
# adam: Epoch=7000 RMSE=0.41681
# adam: Epoch=8000 RMSE=0.41593
# adam: Epoch=9000 RMSE=0.41392
# adam: Epoch=10000 RMSE=0.41255
# NeuralNetwork(9, [10, 10, 10, 10], 1, activation func=Tanh())

# %% [markdown]
# # Weight visualization

# %%
from  matplotlib.colors import LinearSegmentedColormap
cmap = LinearSegmentedColormap.from_list('rg',["r", "w", "g"], N=256) 

columns = ['Hour', 'Temperature(C)', 'Humidity(%)',
          'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(C)',
          'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)']
list(best_model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-1.7510e+00,  4.8075e-02, -4.6112e-01,  4.0085e-02,  2.8738e-02,
#            9.9682e-01,  2.7289e-01,  2.4771e-01, -1.2759e-01],
#          [-1.2257e+00,  7.1050e-02,  5.0667e-01, -5.9286e-02, -1.1942e-01,
#           -2.8629e-01,  6.5235e-01,  1.1332e-01, -1.0610e-01],
#          [-1.3318e-03,  6.3097e-01,  6.1827e-01, -1.0637e-01,  5.3962e-01,
#            3.9614e-01,  1.3894e-01,  2.0694e+00,  1.6149e-02],
#          [ 2.4733e-01, -6.0923e-01, -1.2204e-01,  4.3049e-02, -1.0262e-01,
#            2.7848e-02, -1.1530e-01,  1.2112e+00, -1.4262e-03],
#          [ 6.4068e-01, -6.0028e-01,  2.1556e-01, -8.4092e-02,  2.0716e-02,
#           -3.8153e-01,  2.1406e-01, -1.6550e+00, -7.0901e-02],
#          [-3.7164e-01,  1.4369e+00,  1.0447e+00, -5.2086e-01,  8.6963e-01,
#            6.8833e-01, -8.3720e-02, -1.4771e+00,  7.7734e-02],
#          [ 6.2788e-01, -5.9886e-01,  3.0180e-01, -8.3705e-02,  3.5828e-02,
#           -3.6179e-01, -7.0190e-01,  1.1977e+00, -4.2437e-02],
#          [-6.4634e-01, -1.0351e-01,  3.6920e-01,  1.6997e-02, -5.7790e-02,
#           -9.0669e-01,  1.1749e-01,  7.8960e-02,  2.5065e-02],
#          [-9.4058e-01,  5.6621e-02, -8.2638e-01, -6.2166e-02,  1.3149e-01,
#           -1.1880e-01,  1.5381e-01,  9.8450e-02, -6.6872e-02],
#          [-6.6456e-01, -6.4571e-02,  3.5927e-01, -4.1670e-02,  7.9742e-02,
#           -1.5456e-01, -1.3512e-01, -1.1088e-01,  8.1804e-03]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 1.5905,  0.7839,  0.1649,  0.3346,  0.0983,  0.5034, -0.0274, -0.4850,
#           0.4584,  0.2385], requires_grad=True),
#  Parameter containing:
#  tensor([[-1.1395,  0.8944,  0.2594, -0.1533, -0.5214, -0.1778,  0.3883,  0.8666,
#           -0.6019, -0.0925],
#          [-0.3795, -0.5172, -0.3685,  0.5463,  0.4968,  0.7938, -0.6991,  0.5195,
#           -1.2722,  2.2409],
#          [ 0.2412, -0.1491,  0.2250, -0.3196, -1.1973,  0.1745,  0.4061,  0.0612,
#            1.1300, -0.5192],
#          [ 0.0553,  0.9803,  0.8558,  0.9762, -0.6973, -0.2291,  0.6183, -0.1294,
#           -0.8987, -0.7044],
#          [-1.5894, -0.1872,  0.0842,  0.7256, -0.2891, -0.1462, -0.2303,  0.3826,
#            1.3067, -1.1787],
#          [-2.8464, -0.3419, -0.5278, -3.1465, -0.8664,  0.7512, -2.3556, -0.1989,
#           -0.1752, -0.5839],
#          [-0.5838, -0.0148,  1.0196, -0.5789, -1.6542, -0.3518,  0.3987,  0.1339,
#            0.5419,  0.0666],
#          [-1.5769, -0.0525,  0.7469, -0.7505,  2.8866, -0.6281,  0.1728, -2.0834,
#           -0.4106, -1.9187],
#          [ 1.6699,  0.6503, -0.4862,  1.8576, -0.4586,  0.7681, -0.8168,  1.0136,
#            0.6630,  2.3725],
#          [ 0.6409, -1.1573, -0.2538, -1.6017,  0.0535,  0.4036, -0.6287,  0.4248,
#            1.1061,  0.9975]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.6455, -0.4922,  0.7791,  0.3706, -0.8486, -0.1823, -0.1295,  2.2157,
#           1.1058, -1.0829], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.8003,  0.2295, -0.2436, -0.3355, -0.1019, -1.5065,  1.2475,  0.5869,
#            1.7995, -0.6340],
#          [-0.0051, -0.2446, -0.2595,  0.9080,  3.8573, -2.5718, -2.2820,  0.9754,
#            0.3144,  0.7139],
#          [ 0.0366, -0.0683, -0.4622,  0.2146,  0.4688,  2.2853, -1.4493, -1.4187,
#            2.1426,  0.5407],
#          [-0.1002, -0.3141,  0.5286, -1.3751, -1.2942, -0.8908, -2.1798, -0.3052,
#            1.3698, -0.0816],
#          [ 3.2554, -0.1600, -0.0441, -1.5054,  0.1231,  1.0002,  0.3103, -0.3880,
#           -0.6145,  1.4613],
#          [ 1.7671, -1.8893, -0.3184,  1.7959,  0.8702, -2.4314,  1.6377,  0.1613,
#           -0.2572, -0.4525],
#          [ 2.1429,  0.7460,  1.2876, -1.1692, -0.2880,  0.2398, -0.4367, -0.6143,
#            1.6162,  0.3610],
#          [ 4.6281, -0.2660,  2.3225, -0.7079, -0.7166,  0.5271, -1.5458, -2.1252,
#           -0.5275,  2.4619],
#          [ 4.1657, -0.7327,  0.7284, -1.1944, -0.2639, -0.0691, -0.3512, -2.4194,
#           -1.4193,  1.4954],
#          [-0.3751,  0.2641, -1.9360, -1.4824, -1.8219,  0.7605, -1.5657, -0.1584,
#           -2.2718, -0.1615]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.8874, -0.0288, -0.5907,  0.5375, -0.7129, -0.5463,  0.8452, -1.2235,
#           0.1342, -0.7286], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.2833, -1.3525, -0.4652, -0.2025, -0.4996,  4.4394, -0.7442,  2.6697,
#           -0.1953, -0.7284],
#          [-4.0888,  3.0319,  1.2785,  0.8225,  0.9465, -2.7436, -1.3405,  1.0130,
#           -0.6123, -0.1507],
#          [ 2.8117, -1.5185,  0.8324, -0.1096,  0.6195, -1.5660, -0.1128, -0.0699,
#           -1.2199,  0.9443],
#          [ 1.2137,  1.2800,  0.4985,  0.6951,  1.2298,  1.3988, -0.9300,  0.4934,
#            1.1871, -1.7469],
#          [ 4.0515,  0.0321, -1.1780,  0.4421, -0.2731,  2.2825,  1.5396,  0.1838,
#           -0.3591, -4.8767],
#          [-0.1641, -1.2132, -0.2134, -0.2939, -0.5694,  4.8610, -0.5369,  0.8118,
#            1.7932, -1.1849],
#          [ 0.3202, -0.8786,  0.6799, -2.6388, -0.0615,  2.4276,  0.1151, -0.7723,
#            0.2719, -0.9303],
#          [-0.7725, -0.0717,  1.9523,  0.4051,  0.8062, -1.0783, -1.5407,  0.2659,
#           -1.6171, -0.2168],
#          [ 3.3325,  0.8257, -0.2932, -0.3218,  1.1082,  0.5004,  1.2874, -1.0955,
#           -1.3852, -2.0759],
#          [-0.1627,  0.6572, -0.2443,  0.1881,  0.0956,  2.1351, -0.4636,  0.6477,
#           -2.3609, -0.8850]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.6225,  0.9248, -0.6673, -0.0756, -0.2595,  0.6251,  0.2502, -0.8556,
#          -0.3787,  1.1061], requires_grad=True),
#  Parameter containing:
#  tensor([[ 1.9615,  0.9126,  0.9298,  0.8433, -1.6994, -1.8386, -0.3451,  0.8174,
#            1.1993,  1.0542]], requires_grad=True),
#  Parameter containing:
#  tensor([0.5517], requires_grad=True)]

# %%
# first trained weught (w0) shows how the trained model recognized different attributes
W0 = list(best_model.parameters())[0].detach().numpy()
print(W0.shape)
W0
# Out:
# (10, 9)
# array([[-1.75097418e+00,  4.80753183e-02, -4.61116791e-01,
#          4.00845557e-02,  2.87384875e-02,  9.96820807e-01,
#          2.72893727e-01,  2.47714445e-01, -1.27594382e-01],
#        [-1.22565663e+00,  7.10500330e-02,  5.06668031e-01,
#         -5.92859089e-02, -1.19422533e-01, -2.86286920e-01,
#          6.52352452e-01,  1.13317281e-01, -1.06103957e-01],
#        [-1.33184961e-03,  6.30973816e-01,  6.18267477e-01,
#         -1.06369250e-01,  5.39619386e-01,  3.96138608e-01,
#          1.38939977e-01,  2.06942940e+00,  1.61493272e-02],
#        [ 2.47330844e-01, -6.09233677e-01, -1.22039177e-01,
#          4.30491269e-02, -1.02615014e-01,  2.78477818e-02,
#         -1.15297750e-01,  1.21117413e+00, -1.42617198e-03],
#        [ 6.40679598e-01, -6.00284159e-01,  2.15557218e-01,
#         -8.40916038e-02,  2.07161568e-02, -3.81526589e-01,
#          2.14055374e-01, -1.65495813e+00, -7.09014684e-02],
#        [-3.71644258e-01,  1.43687689e+00,  1.04470861e+00,
#         -5.20856202e-01,  8.69626462e-01,  6.88332021e-01,
#         -8.37201700e-02, -1.47710526e+00,  7.77341202e-02],
#        [ 6.27879620e-01, -5.98856866e-01,  3.01799178e-01,
#         -8.37049410e-02,  3.58278677e-02, -3.61789823e-01,
#         -7.01904476e-01,  1.19767118e+00, -4.24373187e-02],
#        [-6.46341801e-01, -1.03506155e-01,  3.69200259e-01,
#          1.69965699e-02, -5.77900968e-02, -9.06691432e-01,
#          1.17491454e-01,  7.89603069e-02,  2.50645019e-02],
#        [-9.40579474e-01,  5.66208512e-02, -8.26383352e-01,
#         -6.21658042e-02,  1.31491810e-01, -1.18795954e-01,
#          1.53811723e-01,  9.84499529e-02, -6.68722466e-02],
#        [-6.64559066e-01, -6.45713806e-02,  3.59267294e-01,
#         -4.16703597e-02,  7.97416866e-02, -1.54556066e-01,
#         -1.35115191e-01, -1.10879280e-01,  8.18043575e-03]], dtype=float32)

# %%
n_units = W0.shape[0]  # row of weight represents hidden unit, column represents attributes
mx = np.max(np.abs(W0))

plt.imshow(W0, vmin=-mx, vmax=mx, cmap=cmap)
ylabels = ['unit{}'.format(y) for y in range(n_units)]
plt.yticks(range(n_units), ylabels)
plt.xticks(range(len(columns)), columns, rotation=90)
plt.title('Weights of the first layer in the NN')
plt.colorbar()

# %% [markdown]
# From the `Weights of the first layer in the NN` plot, it is visible that variables `Hour, Temperature(C), Humidity(%), Rainfall(mm), Snowfall(cm)` are some of the most significant positive/negative weights assigned in various hidden layers. Therefore, in this model, these variables can be considered as the most important predictors.
#
# Both positive and negative weights have been assigned in the abovementioned variables. For example, `Rainfall` has positive weight assigned in unit 8 and negative in unit 6. This may signify opposite correlation to rainfall event and bike hiring. When rainfall is high bike sharing reduces and vice versa. Similar trends can be seen in weights of `Snowfall`. Bike hiring seems to be strongly correlated to `Hour`. Positive weights in `Hour` might indicate peak hours in which bike hiring is high.

# %%
# My understanding is calculating error by aggregating counties and backpropagating that error is the same as 
# calculating error for each cell (if we has cellwise observed data)
# so we should be able to calculate error by aggregating and then backpropagte it through the network for minimizing

import numpy as np
import pandas as pd
a = np.random.normal(0, 5, size = (150, 150)).reshape(-1, 1)
b = np.random.normal(0, 6, size = (150, 150)).reshape(-1, 1)

df = pd.DataFrame()
df['a'] = list(a.squeeze())
df['b'] = list(b.squeeze())
print('df \n', df.head(5), '\n')

grp_list = [1 if i<10000 else 2 if 10000 <= i < 15000 else 3 for i in range(len(df['a']))]
grp_list = np.random.permutation(grp_list)
df['grp'] = grp_list

df_grp = df.groupby(by='grp').sum()
print('df_grp \n', df_grp, '\n')

rmse_from_pixels = np.sqrt(np.mean((df['a']-df['b'])**2))
print('rmse from pixels', rmse_from_pixels)

rmse_grp = np.sqrt(np.mean((df['a']-df['b'])**2))  
print('rmse grp', rmse_grp)
